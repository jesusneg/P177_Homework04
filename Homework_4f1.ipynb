# %% [markdown]
# # Homework 4: Oscillatory Systems
# Physics 177, Spring 2017 (Prof. Tanedo)
# Due: Tuesday, May 7
#
# *Jesus Negrete*
#
# If there are issues with the homework, please [e-mail Prof. Tanedo](mailto:flip.tanedo@ucr.edu) before the weekend.
#
# **Useful links:**
# * Keyboard shortcuts for Jupyter: https://gist.github.com/kidpixo/f4318f8c8143adee5b40

# %% [markdown]
# ## Problem 1: Simple Pendulum vs. Error Accumulation

# %% [markdown]
# The equations of motion for the simple pendulum are:
#
# $\displaystyle \dot{\theta} = +\, \omega$
# $\displaystyle \dot{\omega} = -\frac{g}{\ell}\sin\theta$
#
# Write these as:
#
# $\displaystyle \dot{\theta} = f(\theta,\omega,t)$
# $\displaystyle \dot{\omega} = h(\theta,\omega,t)$
#
# The pendulum has length $\ell$, angle $\theta$ with respect to the vertical, angular velocity $\omega$, and gravitational acceleration at sea level is $g = 9.8$ m/s$^2$.
#
# **Reminder**: Recall that the Runge-Kutta algorithm for solvine $\dot x = f(x,t)$ is to loop the following sequence of steps:
# `k1 = dt*f(x,t)`
# `k2 = dt*f(x + 0.5*k1, t + 0.5*dt)`
# `x += k2`

# %% [markdown]
# ### 1.a Code this up
#
# Following our example in Lecture 9, code a function `time_and_theta(ell, theta_0)` that outputs two Numpy arrays:
# 1. an array of time slices
# 2. an array of associated $\theta$ values
#
# In other words, the outputs of `time_and_theta(ell, theta_0)` are the required inputs for `matplotlib` to plot the trajectory. Use the Runge-Kutta algorithm to integrate the differential equations. Use MKS units, so that `g = 9.8`.
#
# **Hint**: It is <a href="http://stackoverflow.com/a/930398/4812646">useful to know</a> that you can access the last element of a list using `[-1]` as an index. For example: if `some_list` is `[1,2,3]`, then `some_list[-1]` gives `-3`.
#
# **Remark**: We're using global variables again. This isn't always a good practice, but it will be convenient.

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sin as sin
from math import cos as cos

# CONSTANTS
g = 9.8    

# PARAMETERS
ell = 1.0      # length of pendulum arm
theta_0 = 2.0  # initial displacement in radians
               # Note: this is *not* a small angle
omega_0 = 0.0  # initial angular velocity
dt = 0.01      # time sampling spacing
t_final = 10.0 # total number of seconds to run

def f(theta, omega, t):
    """d(theta)/dt"""
    return omega # FIX THIS
    
def h(theta, omega, t):
    """d(omega)/dt"""
    return -(g/ell)*sin(theta)# FIX THIS

# TIME SLICES (depends on dt and t_final)
tpoints = np.arange(0, t_final, dt)

def time_and_angles():
    """
    Returns three Numpy arrays: 
    1. a list of time samples 
    2. a list of theta values
    3. a list of omega values
    No arguments (these are all assumed to be global variables)
    """
    
    theta_points = []
    omega_points = []
    
    omega = omega_0 # FIX THIS
    theta = theta_0 # FIX THIS
    
    for t in tpoints:
        
        # Record theta, omega
        theta_points.append(theta)
        omega_points.append(omega)
            
        # Time step using Runge-Kutta
        kf = dt*f(theta_points[-1],omega_points[-1],t)
        kf2 = dt*f(theta_points[-1]+.5*kf, omega_points[-1]+0.5*kf, t+0.5*dt)
        theta += kf2 # FIX THIS
        
        kh = dt*h(theta_points[-1],omega_points[-1],t)
        kh2 = dt*h(theta_points[-1]+.5*kh, omega_points[-1]+0.5*kh, t+0.5*dt)
        omega += kh2 # FIX THIS
        
        # Note: the arguments of f(...) and h(...) should use 
        # theta_points[-1] and omega_points[-1].
        #
        # This is to ensure that you update theta and omega simultaneously. 
        # For example, if you were doing Euler (correct):
        # omega(i+1) = omega(i) + dt*f(theta(i), omega(i), t)
        #
        # versus (incorrect)
        # omega(i+1) = omega(i) + dt*f(theta(i+1), omega(i), t)

    tt = np.array(tpoints)
    thetas = np.array(theta_points)
    omegas = np.array(omega_points)
    
    return tt, thetas, omegas

# %%
# Test the above code:
times, thetas, omegas = time_and_angles()

plt.plot(times, thetas, label='$\Theta$ (rad)')
plt.plot(times, omegas, label='$\omega$ (rad/s)')
plt.title("Simple Pendulum")
plt.xlabel('time')
plt.ylabel('Measurements [mks]')
plt.legend()
plt.show()

# %%
print(thetas)
print(omegas)
# Out:
# [  2.00000000e+00   2.00000000e+00   1.99908707e+00   1.99726120e+00
#    1.99452205e+00   1.99086894e+00   1.98630085e+00   1.98081642e+00
#    1.97441398e+00   1.96709155e+00   1.95884686e+00   1.94967734e+00
#    1.93958020e+00   1.92855237e+00   1.91659061e+00   1.90369144e+00
#    1.88985128e+00   1.87506639e+00   1.85933295e+00   1.84264708e+00
#    1.82500491e+00   1.80640259e+00   1.78683635e+00   1.76630256e+00
#    1.74479776e+00   1.72231875e+00   1.69886262e+00   1.67442681e+00
#    1.64900921e+00   1.62260820e+00   1.59522271e+00   1.56685232e+00
#    1.53749733e+00   1.50715882e+00   1.47583874e+00   1.44354000e+00
#    1.41026651e+00   1.37602330e+00   1.34081662e+00   1.30465393e+00
#    1.26754407e+00   1.22949729e+00   1.19052533e+00   1.15064148e+00
#    1.10986066e+00   1.06819947e+00   1.02567624e+00   9.82311062e-01
#    9.38125864e-01   8.93144401e-01   8.47392290e-01   8.00897022e-01
#    7.53687952e-01   7.05796294e-01   6.57255093e-01   6.08099190e-01
#    5.58365174e-01   5.08091322e-01   4.57317529e-01   4.06085218e-01
#    3.54437252e-01   3.02417819e-01   2.50072321e-01   1.97447243e-01
#    1.44590017e-01   9.15488781e-02   3.83727127e-02  -1.48890988e-02
#   -6.81868442e-02  -1.21470644e-01  -1.74690620e-01  -2.27797060e-01
#   -2.80740588e-01  -3.33472324e-01  -3.85944048e-01  -4.38108357e-01
#   -4.89918809e-01  -5.41330068e-01  -5.92298037e-01  -6.42779981e-01
#   -6.92734643e-01  -7.42122339e-01  -7.90905055e-01  -8.39046524e-01
#   -8.86512287e-01  -9.33269751e-01  -9.79288227e-01  -1.02453896e+00
#   -1.06899513e+00  -1.11263188e+00  -1.15542630e+00  -1.19735738e+00
#   -1.23840603e+00  -1.27855500e+00  -1.31778886e+00  -1.35609393e+00
#   -1.39345821e+00  -1.42987136e+00  -1.46532455e+00  -1.49981046e+00
#   -1.53332316e+00  -1.56585803e+00  -1.59741168e+00  -1.62798185e+00
#   -1.65756737e+00  -1.68616803e+00  -1.71378450e+00  -1.74041825e+00
#   -1.76607150e+00  -1.79074709e+00  -1.81444843e+00  -1.83717942e+00
#   -1.85894440e+00  -1.87974802e+00  -1.89959524e+00  -1.91849124e+00
#   -1.93644137e+00  -1.95345105e+00  -1.96952580e+00  -1.98467111e+00
#   -1.99889245e+00  -2.01219519e+00  -2.02458458e+00  -2.03606570e+00
#   -2.04664345e+00  -2.05632249e+00  -2.06510724e+00  -2.07300182e+00
#   -2.08001005e+00  -2.08613544e+00  -2.09138113e+00  -2.09574992e+00
#   -2.09924425e+00  -2.10186613e+00  -2.10361722e+00  -2.10449875e+00
#   -2.10451155e+00  -2.10365605e+00  -2.10193225e+00  -2.09933974e+00
#   -2.09587771e+00  -2.09154493e+00  -2.08633977e+00  -2.08026021e+00
#   -2.07330385e+00  -2.06546791e+00  -2.05674925e+00  -2.04714441e+00
#   -2.03664959e+00  -2.02526068e+00  -2.01297330e+00  -1.99978282e+00
#   -1.98568438e+00  -1.97067293e+00  -1.95474324e+00  -1.93788998e+00
#   -1.92010771e+00  -1.90139096e+00  -1.88173425e+00  -1.86113217e+00
#   -1.83957938e+00  -1.81707073e+00  -1.79360124e+00  -1.76916624e+00
#   -1.74376139e+00  -1.71738274e+00  -1.69002685e+00  -1.66169079e+00
#   -1.63237228e+00  -1.60206974e+00  -1.57078239e+00  -1.53851028e+00
#   -1.50525446e+00  -1.47101700e+00  -1.43580107e+00  -1.39961108e+00
#   -1.36245275e+00  -1.32433313e+00  -1.28526079e+00  -1.24524580e+00
#   -1.20429987e+00  -1.16243639e+00  -1.11967053e+00  -1.07601925e+00
#   -1.03150139e+00  -9.86137709e-01  -9.39950924e-01  -8.92965721e-01
#   -8.45208786e-01  -7.96708804e-01  -7.47496456e-01  -6.97604398e-01
#   -6.47067228e-01  -5.95921442e-01  -5.44205379e-01  -4.91959143e-01
#   -4.39224526e-01  -3.86044902e-01  -3.32465126e-01  -2.78531404e-01
#   -2.24291164e-01  -1.69792914e-01  -1.15086085e-01  -6.02208730e-02
#   -5.24806922e-03   4.97811108e-02   1.04815206e-01   1.59802691e-01
#    2.14692155e-01   2.69432485e-01   3.23973042e-01   3.78263838e-01
#    4.32255707e-01   4.85900467e-01   5.39151075e-01   5.91961778e-01
#    6.44288246e-01   6.96087699e-01   7.47319020e-01   7.97942857e-01
#    8.47921709e-01   8.97220002e-01   9.45804146e-01   9.93642584e-01
#    1.04070582e+00   1.08696645e+00   1.13239916e+00   1.17698069e+00
#    1.22068989e+00   1.26350760e+00   1.30541669e+00   1.34640194e+00
#    1.38645004e+00   1.42554950e+00   1.46369056e+00   1.50086514e+00
#    1.53706676e+00   1.57229042e+00   1.60653255e+00   1.63979088e+00
#    1.67206441e+00   1.70335323e+00   1.73365851e+00   1.76298237e+00
#    1.79132777e+00   1.81869848e+00   1.84509894e+00   1.87053422e+00
#    1.89500989e+00   1.91853199e+00   1.94110695e+00   1.96274148e+00
#    1.98344256e+00   2.00321732e+00   2.02207304e+00   2.04001705e+00
#    2.05705668e+00   2.07319923e+00   2.08845194e+00   2.10282189e+00
#    2.11631600e+00   2.12894101e+00   2.14070341e+00   2.15160943e+00
#    2.16166500e+00   2.17087574e+00   2.17924691e+00   2.18678343e+00
#    2.19348984e+00   2.19937025e+00   2.20442840e+00   2.20866757e+00
#    2.21209063e+00   2.21469999e+00   2.21649760e+00   2.21748497e+00
#    2.21766314e+00   2.21703267e+00   2.21559367e+00   2.21334578e+00
#    2.21028816e+00   2.20641953e+00   2.20173811e+00   2.19624171e+00
#    2.18992767e+00   2.18279291e+00   2.17483389e+00   2.16604669e+00
#    2.15642697e+00   2.14597002e+00   2.13467075e+00   2.12252373e+00
#    2.10952320e+00   2.09566311e+00   2.08093711e+00   2.06533863e+00
#    2.04886089e+00   2.03149690e+00   2.01323955e+00   1.99408162e+00
#    1.97401583e+00   1.95303490e+00   1.93113156e+00   1.90829865e+00
#    1.88452914e+00   1.85981621e+00   1.83415332e+00   1.80753423e+00
#    1.77995315e+00   1.75140472e+00   1.72188416e+00   1.69138732e+00
#    1.65991077e+00   1.62745186e+00   1.59400886e+00   1.55958099e+00
#    1.52416854e+00   1.48777297e+00   1.45039701e+00   1.41204469e+00
#    1.37272151e+00   1.33243448e+00   1.29119223e+00   1.24900508e+00
#    1.20588513e+00   1.16184632e+00   1.11690450e+00   1.07107751e+00
#    1.02438522e+00   9.76849551e-01   9.28494548e-01   8.79346370e-01
#    8.29433314e-01   7.78785807e-01   7.27436393e-01   6.75419704e-01
#    6.22772410e-01   5.69533165e-01   5.15742536e-01   4.61442908e-01
#    4.06678392e-01   3.51494701e-01   2.95939028e-01   2.40059899e-01
#    1.83907027e-01   1.27531146e-01   7.09838377e-02   1.43173547e-02
#   -4.24155670e-02  -9.91618985e-02  -1.55868512e-01  -2.12482376e-01
#   -2.68950752e-01  -3.25221384e-01  -3.81242694e-01  -4.36963959e-01
#   -4.92335495e-01  -5.47308823e-01  -6.01836829e-01  -6.55873912e-01
#   -7.09376120e-01  -7.62301275e-01  -8.14609079e-01  -8.66261212e-01
#   -9.17221411e-01  -9.67455535e-01  -1.01693161e+00  -1.06561988e+00
#   -1.11349281e+00  -1.16052508e+00  -1.20669363e+00  -1.25197756e+00
#   -1.29635818e+00  -1.33981890e+00  -1.38234522e+00  -1.42392464e+00
#   -1.46454659e+00  -1.50420237e+00  -1.54288506e+00  -1.58058940e+00
#   -1.61731176e+00  -1.65304998e+00  -1.68780329e+00  -1.72157226e+00
#   -1.75435863e+00  -1.78616524e+00  -1.81699597e+00  -1.84685559e+00
#   -1.87574968e+00  -1.90368456e+00  -1.93066720e+00  -1.95670510e+00
#   -1.98180626e+00  -2.00597907e+00  -2.02923224e+00  -2.05157476e+00
#   -2.07301577e+00  -2.09356458e+00  -2.11323055e+00  -2.13202306e+00
#   -2.14995146e+00  -2.16702502e+00  -2.18325288e+00  -2.19864403e+00
#   -2.21320725e+00  -2.22695109e+00  -2.23988383e+00  -2.25201346e+00
#   -2.26334763e+00  -2.27389368e+00  -2.28365857e+00  -2.29264885e+00
#   -2.30087071e+00  -2.30832988e+00  -2.31503170e+00  -2.32098102e+00
#   -2.32618228e+00  -2.33063941e+00  -2.33435591e+00  -2.33733477e+00
#   -2.33957850e+00  -2.34108912e+00  -2.34186817e+00  -2.34191667e+00
#   -2.34123515e+00  -2.33982366e+00  -2.33768171e+00  -2.33480836e+00
#   -2.33120214e+00  -2.32686110e+00  -2.32178280e+00  -2.31596431e+00
#   -2.30940224e+00  -2.30209272e+00  -2.29403141e+00  -2.28521353e+00
#   -2.27563387e+00  -2.26528677e+00  -2.25416616e+00  -2.24226559e+00
#   -2.22957820e+00  -2.21609679e+00  -2.20181382e+00  -2.18672140e+00
#   -2.17081140e+00  -2.15407537e+00  -2.13650465e+00  -2.11809039e+00
#   -2.09882354e+00  -2.07869495e+00  -2.05769537e+00  -2.03581550e+00
#   -2.01304605e+00  -1.98937779e+00  -1.96480160e+00  -1.93930853e+00
#   -1.91288984e+00  -1.88553713e+00  -1.85724233e+00  -1.82799783e+00
#   -1.79779653e+00  -1.76663193e+00  -1.73449820e+00  -1.70139032e+00
#   -1.66730407e+00  -1.63223624e+00  -1.59618463e+00  -1.55914820e+00
#   -1.52112714e+00  -1.48212299e+00  -1.44213873e+00  -1.40117886e+00
#   -1.35924952e+00  -1.31635857e+00  -1.27251569e+00  -1.22773244e+00
#   -1.18202236e+00  -1.13540105e+00  -1.08788619e+00  -1.03949765e+00
#   -9.90257504e-01  -9.40190054e-01  -8.89321881e-01  -8.37681833e-01
#   -7.85301027e-01  -7.32212825e-01  -6.78452805e-01  -6.24058705e-01
#   -5.69070361e-01  -5.13529625e-01  -4.57480265e-01  -4.00967856e-01
#   -3.44039653e-01  -2.86744445e-01  -2.29132406e-01  -1.71254925e-01
#   -1.13164430e-01  -5.49141992e-02   3.44183329e-03   6.18492785e-02
#    1.20253500e-01   1.78599822e-01   2.36833742e-01   2.94901136e-01
#    3.52748469e-01   4.10322995e-01   4.67572954e-01   5.24447758e-01
#    5.80898170e-01   6.36876473e-01   6.92336619e-01   7.47234377e-01
#    8.01527453e-01   8.55175605e-01   9.08140737e-01   9.60386976e-01
#    1.01188074e+00   1.06259077e+00   1.11248819e+00   1.16154648e+00
#    1.20974150e+00   1.25705148e+00   1.30345697e+00   1.34894082e+00
#    1.39348811e+00   1.43708609e+00   1.47972411e+00   1.52139355e+00
#    1.56208771e+00   1.60180173e+00   1.64053248e+00   1.67827850e+00
#    1.71503983e+00   1.75081796e+00   1.78561570e+00   1.81943708e+00
#    1.85228726e+00   1.88417239e+00   1.91509957e+00   1.94507668e+00
#    1.97411235e+00   2.00221584e+00   2.02939696e+00   2.05566598e+00
#    2.08103357e+00   2.10551071e+00   2.12910862e+00   2.15183871e+00
#    2.17371250e+00   2.19474158e+00   2.21493753e+00   2.23431191e+00
#    2.25287619e+00   2.27064170e+00   2.28761961e+00   2.30382088e+00
#    2.31925626e+00   2.33393619e+00   2.34787085e+00   2.36107010e+00
#    2.37354346e+00   2.38530008e+00   2.39634874e+00   2.40669783e+00
#    2.41635534e+00   2.42532881e+00   2.43362537e+00   2.44125172e+00
#    2.44821409e+00   2.45451825e+00   2.46016951e+00   2.46517271e+00
#    2.46953221e+00   2.47325189e+00   2.47633515e+00   2.47878490e+00
#    2.48060355e+00   2.48179303e+00   2.48235477e+00   2.48228971e+00
#    2.48159830e+00   2.48028048e+00   2.47833570e+00   2.47576293e+00
#    2.47256064e+00   2.46872680e+00   2.46425891e+00   2.45915397e+00
#    2.45340850e+00   2.44701854e+00   2.43997967e+00   2.43228699e+00
#    2.42393513e+00   2.41491828e+00   2.40523017e+00   2.39486410e+00
#    2.38381291e+00   2.37206906e+00   2.35962457e+00   2.34647108e+00
#    2.33259984e+00   2.31800174e+00   2.30266732e+00   2.28658681e+00
#    2.26975010e+00   2.25214683e+00   2.23376637e+00   2.21459786e+00
#    2.19463026e+00   2.17385236e+00   2.15225283e+00   2.12982026e+00
#    2.10654318e+00   2.08241016e+00   2.05740981e+00   2.03153086e+00
#    2.00476220e+00   1.97709299e+00   1.94851264e+00   1.91901098e+00
#    1.88857826e+00   1.85720526e+00   1.82488336e+00   1.79160465e+00
#    1.75736200e+00   1.72214915e+00   1.68596082e+00   1.64879280e+00
#    1.61064206e+00   1.57150684e+00   1.53138676e+00   1.49028292e+00
#    1.44819803e+00   1.40513647e+00   1.36110441e+00   1.31610991e+00
#    1.27016302e+00   1.22327583e+00   1.17546259e+00   1.12673976e+00
#    1.07712607e+00   1.02664258e+00   9.75312737e-01   9.23162353e-01
#    8.70219666e-01   8.16515323e-01   7.62082359e-01   7.06956170e-01
#    6.51174467e-01   5.94777202e-01   5.37806494e-01   4.80306526e-01
#    4.22323428e-01   3.63905146e-01   3.05101296e-01   2.45962999e-01
#    1.86542706e-01   1.26894014e-01   6.70714621e-02   7.13032826e-03
#   -5.28735872e-02  -1.12884181e-01  -1.72845271e-01  -2.32700821e-01
#   -2.92395164e-01  -3.51873227e-01  -4.11080743e-01  -4.69964469e-01
#   -5.28472381e-01  -5.86553870e-01  -6.44159921e-01  -7.01243280e-01
#   -7.57758607e-01  -8.13662611e-01  -8.68914170e-01  -9.23474436e-01
#   -9.77306920e-01  -1.03037756e+00  -1.08265476e+00  -1.13410945e+00
#   -1.18471507e+00  -1.23444758e+00  -1.28328545e+00  -1.33120964e+00
#   -1.37820352e+00  -1.42425283e+00  -1.46934564e+00  -1.51347221e+00
#   -1.55662498e+00  -1.59879839e+00  -1.63998887e+00  -1.68019467e+00
#   -1.71941577e+00  -1.75765379e+00  -1.79491184e+00  -1.83119445e+00
#   -1.86650743e+00  -1.90085778e+00  -1.93425357e+00  -1.96670383e+00
#   -1.99821846e+00  -2.02880814e+00  -2.05848422e+00  -2.08725863e+00
#   -2.11514380e+00  -2.14215259e+00  -2.16829820e+00  -2.19359411e+00
#   -2.21805397e+00  -2.24169163e+00  -2.26452099e+00  -2.28655598e+00
#   -2.30781053e+00  -2.32829849e+00  -2.34803363e+00  -2.36702955e+00
#   -2.38529968e+00  -2.40285726e+00  -2.41971527e+00  -2.43588643e+00
#   -2.45138318e+00  -2.46621766e+00  -2.48040167e+00  -2.49394667e+00
#   -2.50686378e+00  -2.51916373e+00  -2.53085688e+00  -2.54195320e+00
#   -2.55246226e+00  -2.56239323e+00  -2.57175487e+00  -2.58055550e+00
#   -2.58880305e+00  -2.59650501e+00  -2.60366845e+00  -2.61029999e+00
#   -2.61640584e+00  -2.62199176e+00  -2.62706310e+00  -2.63162475e+00
#   -2.63568118e+00  -2.63923640e+00  -2.64229402e+00  -2.64485718e+00
#   -2.64692860e+00  -2.64851058e+00  -2.64960495e+00  -2.65021313e+00
#   -2.65033610e+00  -2.64997440e+00  -2.64912814e+00  -2.64779700e+00
#   -2.64598022e+00  -2.64367661e+00  -2.64088456e+00  -2.63760199e+00
#   -2.63382644e+00  -2.62955499e+00  -2.62478428e+00  -2.61951055e+00
#   -2.61372958e+00  -2.60743674e+00  -2.60062698e+00  -2.59329480e+00
#   -2.58543429e+00  -2.57703912e+00  -2.56810253e+00  -2.55861735e+00
#   -2.54857599e+00  -2.53797046e+00  -2.52679234e+00  -2.51503283e+00
#   -2.50268273e+00  -2.48973244e+00  -2.47617198e+00  -2.46199102e+00
#   -2.44717882e+00  -2.43172434e+00  -2.41561617e+00  -2.39884258e+00
#   -2.38139155e+00  -2.36325073e+00  -2.34440755e+00  -2.32484915e+00
#   -2.30456248e+00  -2.28353427e+00  -2.26175111e+00  -2.23919944e+00
#   -2.21586562e+00  -2.19173594e+00  -2.16679669e+00  -2.14103419e+00
#   -2.11443486e+00  -2.08698525e+00  -2.05867212e+00  -2.02948247e+00
#   -1.99940368e+00  -1.96842348e+00  -1.93653013e+00  -1.90371242e+00
#   -1.86995980e+00  -1.83526246e+00  -1.79961141e+00  -1.76299859e+00
#   -1.72541697e+00  -1.68686067e+00  -1.64732501e+00  -1.60680669e+00
#   -1.56530385e+00  -1.52281619e+00  -1.47934509e+00  -1.43489372e+00
#   -1.38946711e+00  -1.34307231e+00  -1.29571844e+00  -1.24741681e+00
#   -1.19818096e+00  -1.14802681e+00  -1.09697265e+00  -1.04503926e+00
#   -9.92249900e-01  -9.38630360e-01  -8.84208987e-01  -8.29016667e-01
#   -7.73086813e-01  -7.16455332e-01  -6.59160568e-01  -6.01243237e-01
#   -5.42746333e-01  -4.83715026e-01  -4.24196533e-01  -3.64239977e-01
#   -3.03896233e-01  -2.43217744e-01  -1.82258346e-01  -1.21073053e-01
#   -5.97178551e-02   1.75050821e-03   6.32747773e-02   1.24797407e-01
#    1.86260804e-01   2.47607570e-01   3.08780737e-01   3.69724003e-01
#    4.30381966e-01   4.90700343e-01   5.50626186e-01   6.10108081e-01
#    6.69096342e-01   7.27543180e-01   7.85402865e-01   8.42631868e-01
#    8.99188981e-01   9.55035426e-01   1.01013494e+00   1.06445383e+00
#    1.11796106e+00   1.17062822e+00   1.22242959e+00   1.27334210e+00
#    1.32334534e+00   1.37242147e+00   1.42055525e+00   1.46773387e+00
#    1.51394697e+00   1.55918649e+00   1.60344662e+00   1.64672366e+00
#    1.68901593e+00   1.73032365e+00   1.77064887e+00   1.80999525e+00
#    1.84836807e+00   1.88577401e+00   1.92222109e+00   1.95771853e+00
#    1.99227664e+00   2.02590675e+00   2.05862104e+00   2.09043249e+00
#    2.12135476e+00   2.15140212e+00   2.18058933e+00   2.20893160e+00
#    2.23644449e+00   2.26314382e+00   2.28904566e+00   2.31416619e+00
#    2.33852174e+00   2.36212864e+00   2.38500324e+00   2.40716185e+00
#    2.42862068e+00   2.44939581e+00   2.46950319e+00   2.48895858e+00
#    2.50777753e+00   2.52597535e+00   2.54356710e+00   2.56056759e+00
#    2.57699133e+00   2.59285254e+00   2.60816511e+00   2.62294264e+00
#    2.63719838e+00   2.65094528e+00   2.66419590e+00   2.67696252e+00
#    2.68925703e+00   2.70109098e+00   2.71247560e+00   2.72342174e+00
#    2.73393993e+00   2.74404032e+00   2.75373276e+00   2.76302672e+00
#    2.77193136e+00   2.78045547e+00   2.78860754e+00   2.79639571e+00
#    2.80382779e+00   2.81091128e+00   2.81765335e+00   2.82406085e+00
#    2.83014033e+00   2.83589803e+00   2.84133987e+00   2.84647148e+00
#    2.85129819e+00   2.85582503e+00   2.86005676e+00   2.86399782e+00
#    2.86765240e+00   2.87102437e+00   2.87411736e+00   2.87693469e+00
#    2.87947944e+00   2.88175440e+00   2.88376209e+00   2.88550478e+00
#    2.88698445e+00   2.88820284e+00   2.88916143e+00   2.88986142e+00
#    2.89030377e+00   2.89048918e+00   2.89041809e+00   2.89009067e+00
#    2.88950687e+00   2.88866636e+00   2.88756855e+00   2.88621260e+00
#    2.88459743e+00   2.88272168e+00   2.88058376e+00   2.87818178e+00
#    2.87551364e+00   2.87257694e+00   2.86936904e+00   2.86588703e+00
#    2.86212773e+00   2.85808769e+00   2.85376321e+00   2.84915030e+00
#    2.84424470e+00   2.83904186e+00   2.83353697e+00   2.82772493e+00
#    2.82160035e+00   2.81515756e+00   2.80839058e+00   2.80129316e+00
#    2.79385873e+00   2.78608044e+00   2.77795111e+00   2.76946326e+00
#    2.76060912e+00   2.75138058e+00   2.74176923e+00   2.73176632e+00
#    2.72136280e+00   2.71054929e+00   2.69931607e+00   2.68765312e+00
#    2.67555005e+00   2.66299617e+00   2.64998047e+00   2.63649157e+00
#    2.62251779e+00   2.60804713e+00   2.59306724e+00   2.57756546e+00
#    2.56152882e+00   2.54494405e+00   2.52779754e+00   2.51007543e+00
#    2.49176355e+00   2.47284746e+00   2.45331247e+00   2.43314366e+00]
# [  0.00000000e+00  -9.08391924e-02  -1.81678385e-01  -2.72551793e-01
#   -3.63493391e-01  -4.54536687e-01  -5.45714486e-01  -6.37058667e-01
#   -7.28599942e-01  -8.20367621e-01  -9.12389367e-01  -1.00469095e+00
#   -1.09729600e+00  -1.19022574e+00  -1.28349870e+00  -1.37713052e+00
#   -1.47113356e+00  -1.56551673e+00  -1.66028512e+00  -1.75543973e+00
#   -1.85097719e+00  -1.94688944e+00  -2.04316341e+00  -2.13978075e+00
#   -2.23671749e+00  -2.33394378e+00  -2.43142355e+00  -2.52911428e+00
#   -2.62696666e+00  -2.72492442e+00  -2.82292401e+00  -2.92089446e+00
#   -3.01875715e+00  -3.11642567e+00  -3.21380574e+00  -3.31079513e+00
#   -3.40728362e+00  -3.50315307e+00  -3.59827750e+00  -3.69252325e+00
#   -3.78574923e+00  -3.87780721e+00  -3.96854217e+00  -4.05779280e+00
#   -4.14539201e+00  -4.23116755e+00  -4.31494272e+00  -4.39653712e+00
#   -4.47576752e+00  -4.55244879e+00  -4.62639488e+00  -4.69741988e+00
#   -4.76533910e+00  -4.82997027e+00  -4.89113465e+00  -4.94865831e+00
#   -5.00237327e+00  -5.05211875e+00  -5.09774233e+00  -5.13910114e+00
#   -5.17606296e+00  -5.20850726e+00  -5.23632618e+00  -5.25942548e+00
#   -5.27772526e+00  -5.29116073e+00  -5.29968274e+00  -5.30325825e+00
#   -5.30187066e+00  -5.29551998e+00  -5.28422290e+00  -5.26801267e+00
#   -5.24693889e+00  -5.22106715e+00  -5.19047849e+00  -5.15526882e+00
#   -5.11554814e+00  -5.07143971e+00  -5.02307908e+00  -4.97061306e+00
#   -4.91419861e+00  -4.85400165e+00  -4.79019588e+00  -4.72296151e+00
#   -4.65248400e+00  -4.57895280e+00  -4.50256010e+00  -4.42349964e+00
#   -4.34196545e+00  -4.25815080e+00  -4.17224708e+00  -4.08444279e+00
#   -3.99492262e+00  -3.90386661e+00  -3.81144935e+00  -3.71783935e+00
#   -3.62319838e+00  -3.52768102e+00  -3.43143424e+00  -3.33459703e+00
#   -3.23730018e+00  -3.13966606e+00  -3.04180858e+00  -2.94383309e+00
#   -2.84583644e+00  -2.74790702e+00  -2.65012492e+00  -2.55256207e+00
#   -2.45528245e+00  -2.35834235e+00  -2.26179060e+00  -2.16566887e+00
#   -2.07001195e+00  -1.97484811e+00  -1.88019937e+00  -1.78608185e+00
#   -1.69250612e+00  -1.59947748e+00  -1.50699633e+00  -1.41505847e+00
#   -1.32365542e+00  -1.23277473e+00  -1.14240028e+00  -1.05251257e+00
#   -9.63089017e-01  -8.74104193e-01  -7.85530121e-01  -6.97336512e-01
#   -6.09491017e-01  -5.21959455e-01  -4.34706046e-01  -3.47693631e-01
#   -2.60883882e-01  -1.74237511e-01  -8.77144713e-02  -1.27415760e-03
#    8.51244028e-02   1.71522356e-01   2.57960832e-01   3.44480753e-01
#    4.31122643e-01   5.17926437e-01   6.04931286e-01   6.92175355e-01
#    7.79695626e-01   8.67527687e-01   9.55705520e-01   1.04426128e+00
#    1.13322506e+00   1.22262467e+00   1.31248540e+00   1.40282971e+00
#    1.49367705e+00   1.58504353e+00   1.67694166e+00   1.76938007e+00
#    1.86236318e+00   1.95589093e+00   2.04995847e+00   2.14455580e+00
#    2.23966748e+00   2.33527233e+00   2.43134306e+00   2.52784599e+00
#    2.62474070e+00   2.72197978e+00   2.81950849e+00   2.91726451e+00
#    3.01517768e+00   3.11316982e+00   3.21115446e+00   3.30903677e+00
#    3.40671339e+00   3.50407240e+00   3.60099331e+00   3.69734711e+00
#    3.79299640e+00   3.88779558e+00   3.98159114e+00   4.07422196e+00
#    4.16551980e+00   4.25530982e+00   4.34341117e+00   4.42963769e+00
#    4.51379873e+00   4.59570000e+00   4.67514458e+00   4.75193388e+00
#    4.82586883e+00   4.89675102e+00   4.96438391e+00   5.02857417e+00
#    5.08913288e+00   5.14587696e+00   5.19863040e+00   5.24722564e+00
#    5.29150483e+00   5.33132104e+00   5.36653952e+00   5.39703873e+00
#    5.42271143e+00   5.44346557e+00   5.45922512e+00   5.46993072e+00
#    5.47554030e+00   5.47602940e+00   5.47139154e+00   5.46163822e+00
#    5.44679897e+00   5.42692108e+00   5.40206929e+00   5.37232528e+00
#    5.33778702e+00   5.29856800e+00   5.25479633e+00   5.20661373e+00
#    5.15417441e+00   5.09764389e+00   5.03719771e+00   4.97302013e+00
#    4.90530275e+00   4.83424318e+00   4.76004359e+00   4.68290940e+00
#    4.60304789e+00   4.52066694e+00   4.43597374e+00   4.34917362e+00
#    4.26046896e+00   4.17005811e+00   4.07813452e+00   3.98488581e+00
#    3.89049310e+00   3.79513031e+00   3.69896361e+00   3.60215100e+00
#    3.50484188e+00   3.40717683e+00   3.30928739e+00   3.21129597e+00
#    3.11331579e+00   3.01545091e+00   2.91779634e+00   2.82043816e+00
#    2.72345371e+00   2.62691183e+00   2.53087310e+00   2.43539016e+00
#    2.34050801e+00   2.24626432e+00   2.15268980e+00   2.05980852e+00
#    1.96763830e+00   1.87619104e+00   1.78547307e+00   1.69548550e+00
#    1.60622459e+00   1.51768204e+00   1.42984533e+00   1.34269802e+00
#    1.25622010e+00   1.17038820e+00   1.08517594e+00   1.00055411e+00
#    9.16491017e-01   8.32952644e-01   7.49902917e-01   6.67303905e-01
#    5.85116029e-01   5.03298259e-01   4.21808294e-01   3.40602742e-01
#    2.59637291e-01   1.78866871e-01   9.82458106e-02   1.77279935e-02
#   -6.27329952e-02  -1.43183720e-01  -2.23670752e-01  -3.04240520e-01
#   -3.84939170e-01  -4.65812415e-01  -5.46905389e-01  -6.28262494e-01
#   -7.09927242e-01  -7.91942094e-01  -8.74348294e-01  -9.57185692e-01
#   -1.04049256e+00  -1.12430541e+00  -1.20865877e+00  -1.29358500e+00
#   -1.37911405e+00  -1.46527326e+00  -1.55208705e+00  -1.63957674e+00
#   -1.72776023e+00  -1.81665174e+00  -1.90626150e+00  -1.99659549e+00
#   -2.08765507e+00  -2.17943670e+00  -2.27193158e+00  -2.36512533e+00
#   -2.45899766e+00  -2.55352198e+00  -2.64866510e+00  -2.74438685e+00
#   -2.84063980e+00  -2.93736888e+00  -3.03451111e+00  -3.13199529e+00
#   -3.22974175e+00  -3.32766215e+00  -3.42565922e+00  -3.52362667e+00
#   -3.62144907e+00  -3.71900182e+00  -3.81615116e+00  -3.91275426e+00
#   -4.00865942e+00  -4.10370627e+00  -4.19772617e+00  -4.29054257e+00
#   -4.38197161e+00  -4.47182267e+00  -4.55989917e+00  -4.64599931e+00
#   -4.72991705e+00  -4.81144309e+00  -4.89036598e+00  -4.96647330e+00
#   -5.03955293e+00  -5.10939434e+00  -5.17579000e+00  -5.23853674e+00
#   -5.29743725e+00  -5.35230145e+00  -5.40294798e+00  -5.44920560e+00
#   -5.49091451e+00  -5.52792774e+00  -5.56011231e+00  -5.58735041e+00
#   -5.60954043e+00  -5.62659784e+00  -5.63845602e+00  -5.64506683e+00
#   -5.64640114e+00  -5.64244911e+00  -5.63322033e+00  -5.61874384e+00
#   -5.59906790e+00  -5.57425962e+00  -5.54440448e+00  -5.50960559e+00
#   -5.46998292e+00  -5.42567225e+00  -5.37682417e+00  -5.32360281e+00
#   -5.26618453e+00  -5.20475661e+00  -5.13951574e+00  -5.07066660e+00
#   -4.99842030e+00  -4.92299292e+00  -4.84460400e+00  -4.76347508e+00
#   -4.67982824e+00  -4.59388482e+00  -4.50586407e+00  -4.41598195e+00
#   -4.32445005e+00  -4.23147456e+00  -4.13725536e+00  -4.04198521e+00
#   -3.94584907e+00  -3.84902354e+00  -3.75167632e+00  -3.65396589e+00
#   -3.55604119e+00  -3.45804148e+00  -3.36009620e+00  -3.26232497e+00
#   -3.16483764e+00  -3.06773441e+00  -2.97110597e+00  -2.87503377e+00
#   -2.77959027e+00  -2.68483921e+00  -2.59083597e+00  -2.49762790e+00
#   -2.40525471e+00  -2.31374879e+00  -2.22313566e+00  -2.13343434e+00
#   -2.04465768e+00  -1.95681280e+00  -1.86990145e+00  -1.78392036e+00
#   -1.69886157e+00  -1.61471284e+00  -1.53145790e+00  -1.44907679e+00
#   -1.36754618e+00  -1.28683960e+00  -1.20692776e+00  -1.12777875e+00
#   -1.04935832e+00  -9.71630072e-01  -8.94555668e-01  -8.18095040e-01
#   -7.42206560e-01  -6.66847208e-01  -5.91972737e-01  -5.17537816e-01
#   -4.43496168e-01  -3.69800703e-01  -2.96403638e-01  -2.23256617e-01
#   -1.50310813e-01  -7.75170399e-02  -4.82585173e-03   6.78123609e-02
#    1.40447274e-01   2.13128536e-01   2.85905672e-01   3.58827994e-01
#    4.31944499e-01   5.05303775e-01   5.78953898e-01   6.52942325e-01
#    7.27315788e-01   8.02120174e-01   8.77400404e-01   9.53200300e-01
#    1.02956245e+00   1.10652806e+00   1.18413679e+00   1.26242660e+00
#    1.34143354e+00   1.42119160e+00   1.50173246e+00   1.58308531e+00
#    1.66527659e+00   1.74832976e+00   1.83226502e+00   1.91709906e+00
#    2.00284476e+00   2.08951086e+00   2.17710168e+00   2.26561678e+00
#    2.35505058e+00   2.44539207e+00   2.53662441e+00   2.62872454e+00
#    2.72166287e+00   2.81540286e+00   2.90990066e+00   3.00510476e+00
#    3.10095560e+00   3.19738528e+00   3.29431723e+00   3.39166590e+00
#    3.48933652e+00   3.58722489e+00   3.68521719e+00   3.78318991e+00
#    3.88100975e+00   3.97853368e+00   4.07560899e+00   4.17207351e+00
#    4.26775586e+00   4.36247580e+00   4.45604475e+00   4.54826626e+00
#    4.63893681e+00   4.72784649e+00   4.81477997e+00   4.89951745e+00
#    4.98183581e+00   5.06150977e+00   5.13831321e+00   5.21202053e+00
#    5.28240810e+00   5.34925573e+00   5.41234824e+00   5.47147699e+00
#    5.52644144e+00   5.57705075e+00   5.62312522e+00   5.66449786e+00
#    5.70101571e+00   5.73254119e+00   5.75895331e+00   5.78014878e+00
#    5.79604289e+00   5.80657039e+00   5.81168609e+00   5.81136532e+00
#    5.80560423e+00   5.79441987e+00   5.77785015e+00   5.75595353e+00
#    5.72880857e+00   5.69651331e+00   5.65918446e+00   5.61695646e+00
#    5.56998035e+00   5.51842254e+00   5.46246346e+00   5.40229613e+00
#    5.33812459e+00   5.27016236e+00   5.19863079e+00   5.12375747e+00
#    5.04577451e+00   4.96491705e+00   4.88142157e+00   4.79552448e+00
#    4.70746062e+00   4.61746194e+00   4.52575624e+00   4.43256602e+00
#    4.33810745e+00   4.24258945e+00   4.14621289e+00   4.04916993e+00
#    3.95164345e+00   3.85380658e+00   3.75582240e+00   3.65784371e+00
#    3.56001288e+00   3.46246179e+00   3.36531192e+00   3.26867443e+00
#    3.17265031e+00   3.07733067e+00   2.98279699e+00   2.88912143e+00
#    2.79636721e+00   2.70458896e+00   2.61383315e+00   2.52413847e+00
#    2.43553625e+00   2.34805092e+00   2.26170038e+00   2.17649644e+00
#    2.09244521e+00   2.00954751e+00   1.92779926e+00   1.84719183e+00
#    1.76771239e+00   1.68934426e+00   1.61206723e+00   1.53585786e+00
#    1.46068973e+00   1.38653377e+00   1.31335846e+00   1.24113006e+00
#    1.16981285e+00   1.09936933e+00   1.02976038e+00   9.60945441e-01
#    8.92882676e-01   8.25529108e-01   7.58840750e-01   6.92772728e-01
#    6.27279385e-01   5.62314385e-01   4.97830803e-01   4.33781203e-01
#    3.70117720e-01   3.06792124e-01   2.43755887e-01   1.80960237e-01
#    1.18356215e-01   5.58947262e-02  -6.47341508e-03  -6.87974379e-02
#   -1.31126571e-01  -1.93510001e-01  -2.55996827e-01  -3.18636018e-01
#   -3.81476369e-01  -4.44566453e-01  -5.07954574e-01  -5.71688711e-01
#   -6.35816466e-01  -7.00385002e-01  -7.65440977e-01  -8.31030469e-01
#   -8.97198906e-01  -9.63990970e-01  -1.03145051e+00  -1.09962044e+00
#   -1.16854262e+00  -1.23825773e+00  -1.30880515e+00  -1.38022282e+00
#   -1.45254704e+00  -1.52581235e+00  -1.60005130e+00  -1.67529429e+00
#   -1.75156930e+00  -1.82890172e+00  -1.90731407e+00  -1.98682572e+00
#   -2.06745264e+00  -2.14920707e+00  -2.23209726e+00  -2.31612705e+00
#   -2.40129562e+00  -2.48759707e+00  -2.57502006e+00  -2.66354744e+00
#   -2.75315583e+00  -2.84381524e+00  -2.93548866e+00  -3.02813167e+00
#   -3.12169201e+00  -3.21610919e+00  -3.31131416e+00  -3.40722888e+00
#   -3.50376605e+00  -3.60082876e+00  -3.69831025e+00  -3.79609371e+00
#   -3.89405209e+00  -3.99204802e+00  -4.08993378e+00  -4.18755136e+00
#   -4.28473260e+00  -4.38129944e+00  -4.47706421e+00  -4.57183016e+00
#   -4.66539194e+00  -4.75753634e+00  -4.84804304e+00  -4.93668555e+00
#   -5.02323225e+00  -5.10744752e+00  -5.18909300e+00  -5.26792897e+00
#   -5.34371577e+00  -5.41621535e+00  -5.48519286e+00  -5.55041828e+00
#   -5.61166813e+00  -5.66872712e+00  -5.72138987e+00  -5.76946251e+00
#   -5.81276435e+00  -5.85112938e+00  -5.88440771e+00  -5.91246691e+00
#   -5.93519325e+00  -5.95249272e+00  -5.96429193e+00  -5.97053886e+00
#   -5.97120338e+00  -5.96627763e+00  -5.95577610e+00  -5.93973564e+00
#   -5.91821516e+00  -5.89129518e+00  -5.85907719e+00  -5.82168277e+00
#   -5.77925263e+00  -5.73194539e+00  -5.67993626e+00  -5.62341561e+00
#   -5.56258740e+00  -5.49766756e+00  -5.42888223e+00  -5.35646607e+00
#   -5.28066045e+00  -5.20171173e+00  -5.11986946e+00  -5.03538473e+00
#   -4.94850855e+00  -4.85949024e+00  -4.76857604e+00  -4.67600771e+00
#   -4.58202136e+00  -4.48684626e+00  -4.39070393e+00  -4.29380728e+00
#   -4.19635986e+00  -4.09855530e+00  -4.00057687e+00  -3.90259708e+00
#   -3.80477751e+00  -3.70726867e+00  -3.61020994e+00  -3.51372971e+00
#   -3.41794543e+00  -3.32296391e+00  -3.22888150e+00  -3.13578449e+00
#   -3.04374944e+00  -2.95284355e+00  -2.86312513e+00  -2.77464401e+00
#   -2.68744198e+00  -2.60155330e+00  -2.51700510e+00  -2.43381786e+00
#   -2.35200587e+00  -2.27157767e+00  -2.19253645e+00  -2.11488048e+00
#   -2.03860351e+00  -1.96369513e+00  -1.89014114e+00  -1.81792389e+00
#   -1.74702259e+00  -1.67741361e+00  -1.60907077e+00  -1.54196557e+00
#   -1.47606749e+00  -1.41134414e+00  -1.34776152e+00  -1.28528420e+00
#   -1.22387547e+00  -1.16349750e+00  -1.10411152e+00  -1.04567792e+00
#   -9.88156356e-01  -9.31505881e-01  -8.75685027e-01  -8.20651894e-01
#   -7.66364217e-01  -7.12779439e-01  -6.59854763e-01  -6.07547206e-01
#   -5.55813641e-01  -5.04610832e-01  -4.53895470e-01  -4.03624194e-01
#   -3.53753618e-01  -3.04240345e-01  -2.55040986e-01  -2.06112162e-01
#   -1.57410525e-01  -1.08892753e-01  -6.05155583e-02  -1.22356925e-02
#    3.59900560e-02   8.42048601e-02   1.32451854e-01   1.80774133e-01
#    2.29214754e-01   2.77816737e-01   3.26623058e-01   3.75676654e-01
#    4.25020413e-01   4.74697171e-01   5.24749703e-01   5.75220711e-01
#    6.26152814e-01   6.77588525e-01   7.29570234e-01   7.82140180e-01
#    8.35340421e-01   8.89212801e-01   9.43798903e-01   9.99140005e-01
#    1.05527702e+00   1.11225045e+00   1.17010029e+00   1.22886596e+00
#    1.28858622e+00   1.34929907e+00   1.41104163e+00   1.47385003e+00
#    1.53775926e+00   1.60280305e+00   1.66901366e+00   1.73642175e+00
#    1.80505618e+00   1.87494378e+00   1.94610912e+00   2.01857432e+00
#    2.09235872e+00   2.16747866e+00   2.24394715e+00   2.32177357e+00
#    2.40096330e+00   2.48151745e+00   2.56343240e+00   2.64669947e+00
#    2.73130451e+00   2.81722747e+00   2.90444201e+00   2.99291504e+00
#    3.08260627e+00   3.17346782e+00   3.26544374e+00   3.35846959e+00
#    3.45247205e+00   3.54736848e+00   3.64306657e+00   3.73946403e+00
#    3.83644825e+00   3.93389607e+00   4.03167360e+00   4.12963608e+00
#    4.22762786e+00   4.32548239e+00   4.42302244e+00   4.52006023e+00
#    4.61639787e+00   4.71182776e+00   4.80613321e+00   4.89908912e+00
#    4.99046288e+00   5.08001528e+00   5.16750162e+00   5.25267299e+00
#    5.33527754e+00   5.41506199e+00   5.49177315e+00   5.56515958e+00
#    5.63497329e+00   5.70097152e+00   5.76291853e+00   5.82058742e+00
#    5.87376191e+00   5.92223814e+00   5.96582640e+00   6.00435273e+00
#    6.03766051e+00   6.06561183e+00   6.08808884e+00   6.10499479e+00
#    6.11625505e+00   6.12181782e+00   6.12165467e+00   6.11576095e+00
#    6.10415582e+00   6.08688224e+00   6.06400660e+00   6.03561821e+00
#    6.00182857e+00   5.96277041e+00   5.91859655e+00   5.86947866e+00
#    5.81560576e+00   5.75718263e+00   5.69442814e+00   5.62757346e+00
#    5.55686020e+00   5.48253854e+00   5.40486532e+00   5.32410212e+00
#    5.24051347e+00   5.15436498e+00   5.06592166e+00   4.97544627e+00
#    4.88319778e+00   4.78942998e+00   4.69439023e+00   4.59831826e+00
#    4.50144525e+00   4.40399292e+00   4.30617285e+00   4.20818591e+00
#    4.11022181e+00   4.01245881e+00   3.91506355e+00   3.81819091e+00
#    3.72198412e+00   3.62657482e+00   3.53208326e+00   3.43861862e+00
#    3.34627925e+00   3.25515312e+00   3.16531823e+00   3.07684300e+00
#    2.98978682e+00   2.90420046e+00   2.82012665e+00   2.73760049e+00
#    2.65665005e+00   2.57729676e+00   2.49955597e+00   2.42343737e+00
#    2.34894547e+00   2.27608005e+00   2.20483651e+00   2.13520636e+00
#    2.06717751e+00   2.00073468e+00   1.93585970e+00   1.87253185e+00
#    1.81072812e+00   1.75042350e+00   1.69159122e+00   1.63420297e+00
#    1.57822914e+00   1.52363898e+00   1.47040083e+00   1.41848220e+00
#    1.36784999e+00   1.31847059e+00   1.27031002e+00   1.22333400e+00
#    1.17750807e+00   1.13279771e+00   1.08916835e+00   1.04658546e+00
#    1.00501466e+00   9.64421689e-01   9.24772510e-01   8.86033320e-01
#    8.48170592e-01   8.11151098e-01   7.74941931e-01   7.39510524e-01
#    7.04824660e-01   6.70852486e-01   6.37562517e-01   6.04923638e-01
#    5.72905107e-01   5.41476552e-01   5.10607965e-01   4.80269702e-01
#    4.50432469e-01   4.21067313e-01   3.92145617e-01   3.63639082e-01
#    3.35519715e-01   3.07759818e-01   2.80331968e-01   2.53209007e-01
#    2.26364021e-01   1.99770323e-01   1.73401440e-01   1.47231088e-01
#    1.21233160e-01   9.53817048e-02   6.96509060e-02   4.40150661e-02
#    1.84485854e-02  -7.07405733e-03  -3.25783239e-02  -5.80896369e-02
#   -8.36333988e-02  -1.09235012e-01  -1.34919898e-01  -1.60713516e-01
#   -1.86641385e-01  -2.12729098e-01  -2.39002346e-01  -2.65486934e-01
#   -2.92208798e-01  -3.19194024e-01  -3.46468867e-01  -3.74059766e-01
#   -4.01993361e-01  -4.30296508e-01  -4.58996295e-01  -4.88120055e-01
#   -5.17695383e-01  -5.47750141e-01  -5.78312478e-01  -6.09410833e-01
#   -6.41073948e-01  -6.73330874e-01  -7.06210973e-01  -7.39743928e-01
#   -7.73959740e-01  -8.08888729e-01  -8.44561527e-01  -8.81009080e-01
#   -9.18262631e-01  -9.56353710e-01  -9.95314121e-01  -1.03517592e+00
#   -1.07597138e+00  -1.11773299e+00  -1.16049338e+00  -1.20428533e+00
#   -1.24914166e+00  -1.29509525e+00  -1.34217891e+00  -1.39042536e+00
#   -1.43986714e+00  -1.49053651e+00  -1.54246536e+00  -1.59568511e+00
#   -1.65022659e+00  -1.70611990e+00  -1.76339428e+00  -1.82207793e+00
#   -1.88219785e+00  -1.94377967e+00  -2.00684742e+00  -2.07142330e+00]

# %% [markdown]
# Your code above should produce:
# <img src="HW4_simple_pendulum.png">

# %% [markdown]
# ### 1.b Phase Space
#
# Using your code (or rewriting it if necessary) from Problem 1.a, plot the **phase space trajectory** of the simple pendulum over the range 0 to 10 seconds with the initial conditiosn above. A phase space diagram has $\theta$ on the horizontal axis and momentum on the vertical axis. You may assume that the pendulum weight has unit mass.
#
# (In the units where `g=9.8`, what does "unit mass" mean?)
#
# **Explain what's going on.** The result may surprise you. But then you'll remember the discussion we had at the end of Lecture 9 about energy conservation and the propagation of errors. Start by explaining what kind of physics diagram you expect to see (based on physics), and then explain why this diagram looks different.

# %%
# FIll this in
mass = 1
g = 9.8    
# PARAMETERS
ell = 1.0      # length of pendulum arm
theta_0 = 2.0  # initial displacement in radians
               # Note: this is *not* a small angle
omega_0 = 0.0  # initial angular velocity
dt = 0.01      # time sampling spacing
t_final = 10.0# total number of seconds to run

momentum_0=0
tpoints = np.arange(0, t_final, dt)

def Moment(theta,omega,t):
    return ell*mass*ell*omega*sin(theta)

momentum_point=[]
theta_points = []
omega_points = []

omega = omega_0 # FIX THIS
theta = theta_0
momentum = momentum_0


for t in tpoints:
    momentum_point.append(momentum)
    
    theta_points.append(theta)
    omega_points.append(omega)
            
    kf = dt*f(theta_points[-1],omega_points[-1],t)
    kf2 = dt*f(theta_points[-1]+.5*kf, omega_points[-1]+0.5*kf, t+0.5*dt)
    theta += kf2 # FIX THIS
        
    kh = dt*h(theta_points[-1],omega_points[-1],t)
    kh2 = dt*h(theta_points[-1]+.5*kh, omega_points[-1]+0.5*kh, t+0.5*dt)
    omega += kh2 # FIX THIS   
    
    km1 = dt*Moment(theta_points[-1],omega_points[-1],t)
    km2 = dt*Moment(theta_points[-1]+.5*km1, omega_points[-1]+0.5*km1, t+0.5*dt)
    momentum += km2
    
PP = np.array(momentum_point)
tt = np.array(tpoints)
thetas = np.array(theta_points)
omegas = np.array(omega_points)

plt.plot(thetas, PP, label='Trajectory')
plt.title("Phase Space Trajectory")
plt.xlabel('angle')
plt.ylabel('Momentum')
plt.legend()
plt.show()

# %%
mass = 1
g = 9.8    
# PARAMETERS
ell = 1.0      # length of pendulum arm
theta_0 = 2.0  # initial displacement in radians
               # Note: this is *not* a small angle
omega_0 = 0.0  # initial angular velocity
dt = 0.01      # time sampling spacing
t_final = 10.0# total number of seconds to run


tpoints = np.arange(0, t_final, dt)

theta_points = []
omega_points = []

omega = omega_0 # FIX THIS
theta = theta_0

for t in tpoints:
    
    theta_points.append(theta)
    omega_points.append(omega)
            
    kf = dt*f(theta_points[-1],omega_points[-1],t)
    kf2 = dt*f(theta_points[-1]+.5*kf, omega_points[-1]+0.5*kf, t+0.5*dt)
    theta += kf2 # FIX THIS
        
    kh = dt*h(theta_points[-1],omega_points[-1],t)
    kh2 = dt*h(theta_points[-1]+.5*kh, omega_points[-1]+0.5*kh, t+0.5*dt)
    omega += kh2 # FIX THIS   
            
tt = np.array(tpoints)
thetas = np.array(theta_points)
omegas = np.array(omega_points)
Momentum = mass*ell**2*omegas*np.sin(thetas)
Moment = mass*ell**2*omegas

plt.plot(thetas, Momentum, label='Trajectory')
plt.plot(thetas, Moment, label='Trajectory2')
plt.title("Phase Space Trajectory")
plt.xlabel('angle')
plt.ylabel('Momentum')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.c Plot of Energy with Respect to Time
#
# The energy of the simple pendulum is
#
# $\displaystyle E = \frac{1}{2} m \ell^2 \omega^2 + m g \ell \left(1-\cos\theta\right)$
#
# **Hint:** Numpy arrays are "built" for being manipulated as mathematical objects. Thus it may be useful to observe the following operations:

# %%
test_numpy_array=np.array([3.14,1.55])
np.cos(test_numpy_array)
# Out:
# array([-0.99999873,  0.02079483])

# %%
test_numpy_array**2
# Out:
# array([ 9.8596,  2.4025])

# %% [markdown]
# Using the outputs of your code from Problem 1.a, create a Numpy array of energy at each time step and plot energy as a function of time. Refer to your answer to Problem 1.b and explain what's going on. From physical principles, what do you *expect* this plot to look like (e.g. if you were taking measurements of an actual simple pendulum).

# %%
m = 1.0

g = 9.8    
# PARAMETERS
ell = 1.0      # length of pendulum arm
theta_0 = 2.0  # initial displacement in radians
               # Note: this is *not* a small angle
omega_0 = 0.0  # initial angular velocity
dt = 0.01      # time sampling spacing
t_final = 10.0# total number of seconds to run

tpoints = np.arange(0, t_final, dt)

theta_points = []
omega_points = []

omega = omega_0 # FIX THIS
theta = theta_0

for t in tpoints:
    
    theta_points.append(theta)
    omega_points.append(omega)
            
    kf = dt*f(theta_points[-1],omega_points[-1],t)
    kf2 = dt*f(theta_points[-1]+.5*kf, omega_points[-1]+0.5*kf, t+0.5*dt)
    theta += kf2 # FIX THIS
        
    kh = dt*h(theta_points[-1],omega_points[-1],t)
    kh2 = dt*h(theta_points[-1]+.5*kh, omega_points[-1]+0.5*kh, t+0.5*dt)
    omega += kh2 # FIX THIS   
            
tt = np.array(tpoints)
thetas = np.array(theta_points)
omegas = np.array(omega_points)
Energy = .5*m*ell**2*omegas**2 + m*g*ell*(1-np.cos(thetas))

plt.plot(tt, Energy, label='Evt')
plt.title("Energy conservation")
plt.xlabel('Time')
plt.ylabel('Energy')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.d Time-reversal symmetry in Runge-Kutta
#
# As we discussed in lecture, the weird behavior observed in Problems 1.b and 1.c (and that are barely visible in the plot from 1.a) are due to the Runge-Kutta algorithm breaking time-reversal invariance. This means that total energy drifts, and we argued that the drift is positive definite. If you didn't observe this, go back and fix your answers to 1.b and 1.c right now.
#
# It is useful to know that given an array, `some_array`, you can produce the same array in the "reverse order" using `some_array[::-1]`.
#
# Use your code exisiting code to redo the *same* simple pendulum system, except whith `theta_0` set to the *final* value (`thetas[-1]`), `omega_0` set to the *final* value (`omegas[-1]`), and `dt` set to be negative (`dt = -0.01`). You'll have to also reverse the `tpoints` array of time samples.

# %%
theta_0 = 2.43314366 # FIX THIS
omega_0 = -2.07142330 # FIX THIS
dt = -.01 # FIX THIS )
t_final = 10

# we want tpoints to be the "reverse" of what it was in problem 1.a
# so that the last time step appears first, and t=0 appears last
tpoints = np.arange(t_final, 0, dt) # FIX THIS

# Now we just run the *same* code from problem 1.a
back_times, back_thetas, back_omegas = time_and_angles()

# CLEAN UP
# (Return global values back to their original values)
theta_0 = 2
omega_0 = 0
 
tpoints = np.arange(0, t_final, abs(dt))
times,thetas,omegas = time_and_angles()

# Compare plots
plt.plot(times, thetas, label='Running forward from initial condition')
plt.plot(back_times, back_thetas, label='Running backward from final condition')
plt.title("Simple Pendulum in Runge-Kutta: Time Reversal")
plt.xlabel('time')
plt.ylabel('Theta [rad]')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.e Leap-Frog to the Rescue
#
# Use the leap-frog algorithm described in class to re-code `time_and_angles()`. Recall that at each step of leapfrog, you have `x[i]` and `x[i+1/2` and do the following:
#
# 1. `x[i+1]` is defined as `x[i]` plus a correction whose slop comes from `f(x,t)` evaluated at `x[i+1/2]` and `t[i+1/2]`.
# 2. `x[i+3/2]` is defined as `x[i+1/2]` plus a correction whose slop comes from `f(x,t)` evaluated at `x[i+1]` and `t[i+1]`.

# %%
dt = 0.01      # time sampling spacing
t_final = 10.0# total number of seconds to run

tpoints = np.arange(0, t_final, dt)
def time_and_angles_leapfrog():
    """
    Returns three Numpy arrays: 
    1. a list of time samples 
    2. a list of theta values
    3. a list of omega values
    No arguments (these are all assumed to be global variables)
    Uses leap-frog algorithm
    """
    dt = 0.01      # time sampling spacing
    t_final = 10.0# total number of seconds to run

    tpoints = np.arange(0, t_final, dt)
    
    theta_points = []
    omega_points = []
    
    # Initialize theta, omega
    theta_0 = 2
    omega_0 = 0
    theta = theta_0
    omega = omega_0
    
    # Initialize theta, omega "+1/2"
    theta_half = theta + .5 # FILL THIS IN USING ONE STEP OF THE EULER METHOD
    omega_half = omega + .5# FILL THIS IN USING ONE STEP OF THE EULER METHOD
    
    
    for t in tpoints:
        # Record theta, omega
        #kf = dt*f(theta_points[-1],omega_points[-1],t)
        #kf2 = dt*f(theta_points[-1]+.5*kf, omega_points[-1]+0.5*kf, t+0.5*dt)
        #theta += kf2
        theta_points.append(theta)
        omega_points.append(omega)
            
        # Time step using Leap-Frog
        Lft1 = dt*f(theta_points[-1],omega_points[-1],t) 
        Lft2 = dt*f(theta_points[-1]+.5*Lft1, omega_points[-1] +.5*Lft1, t + .5*dt)
        Lft3 = dt*f(theta_points[-1] + Lft2, omega_points[-1] + Lft2, t + dt)
        Lft4 = dt*f(theta_points[-1] + .5*Lft1 + Lft3, omega_points[-1] + .5*Lft1 + Lft3, t + (3/2)*dt ) 
        Lft5 = theta_points[-1] + Lft2 + Lft4
        theta += Lft2 
        
        Lfw1 = dt*h(theta_points[-1],omega_points[-1],t) 
        Lfw2 = dt*h(theta_points[-1]+.5*Lfw1, omega_points[-1] +.5*Lfw1, t + .5*dt)
        Lfw3 = dt*h(theta_points[-1] + Lfw2, omega_points[-1] + Lfw2, t + dt)
        Lfw4 = dt*h(theta_points[-1] + .5*Lfw1 + Lfw3, omega_points[-1] + .5*Lfw1 + Lfw3, t + (3/2)*dt ) 
        Lfw5 = omega_points[-1] + Lfw2 + Lfw4
        omega += Lfw2
        # FILL THIS IN
        
    tt = np.array(tpoints)
    thetas = np.array(theta_points)
    omegas = np.array(omega_points)
    
    return tt, thetas, omegas

# Test the above code:
times, thetas_lf, omegas_lf = time_and_angles_leapfrog()
print(thetas_lf)
print(omegas_lf)
# Out:
# [  2.00000000e+00   2.00000000e+00   1.99908707e+00   1.99726120e+00
#    1.99452205e+00   1.99086894e+00   1.98630085e+00   1.98081642e+00
#    1.97441398e+00   1.96709155e+00   1.95884686e+00   1.94967734e+00
#    1.93958020e+00   1.92855237e+00   1.91659061e+00   1.90369144e+00
#    1.88985128e+00   1.87506639e+00   1.85933295e+00   1.84264708e+00
#    1.82500491e+00   1.80640259e+00   1.78683635e+00   1.76630256e+00
#    1.74479776e+00   1.72231875e+00   1.69886262e+00   1.67442681e+00
#    1.64900921e+00   1.62260820e+00   1.59522271e+00   1.56685232e+00
#    1.53749733e+00   1.50715882e+00   1.47583874e+00   1.44354000e+00
#    1.41026651e+00   1.37602330e+00   1.34081662e+00   1.30465393e+00
#    1.26754407e+00   1.22949729e+00   1.19052533e+00   1.15064148e+00
#    1.10986066e+00   1.06819947e+00   1.02567624e+00   9.82311062e-01
#    9.38125864e-01   8.93144401e-01   8.47392290e-01   8.00897022e-01
#    7.53687952e-01   7.05796294e-01   6.57255093e-01   6.08099190e-01
#    5.58365174e-01   5.08091322e-01   4.57317529e-01   4.06085218e-01
#    3.54437252e-01   3.02417819e-01   2.50072321e-01   1.97447243e-01
#    1.44590017e-01   9.15488781e-02   3.83727127e-02  -1.48890988e-02
#   -6.81868442e-02  -1.21470644e-01  -1.74690620e-01  -2.27797060e-01
#   -2.80740588e-01  -3.33472324e-01  -3.85944048e-01  -4.38108357e-01
#   -4.89918809e-01  -5.41330068e-01  -5.92298037e-01  -6.42779981e-01
#   -6.92734643e-01  -7.42122339e-01  -7.90905055e-01  -8.39046524e-01
#   -8.86512287e-01  -9.33269751e-01  -9.79288227e-01  -1.02453896e+00
#   -1.06899513e+00  -1.11263188e+00  -1.15542630e+00  -1.19735738e+00
#   -1.23840603e+00  -1.27855500e+00  -1.31778886e+00  -1.35609393e+00
#   -1.39345821e+00  -1.42987136e+00  -1.46532455e+00  -1.49981046e+00
#   -1.53332316e+00  -1.56585803e+00  -1.59741168e+00  -1.62798185e+00
#   -1.65756737e+00  -1.68616803e+00  -1.71378450e+00  -1.74041825e+00
#   -1.76607150e+00  -1.79074709e+00  -1.81444843e+00  -1.83717942e+00
#   -1.85894440e+00  -1.87974802e+00  -1.89959524e+00  -1.91849124e+00
#   -1.93644137e+00  -1.95345105e+00  -1.96952580e+00  -1.98467111e+00
#   -1.99889245e+00  -2.01219519e+00  -2.02458458e+00  -2.03606570e+00
#   -2.04664345e+00  -2.05632249e+00  -2.06510724e+00  -2.07300182e+00
#   -2.08001005e+00  -2.08613544e+00  -2.09138113e+00  -2.09574992e+00
#   -2.09924425e+00  -2.10186613e+00  -2.10361722e+00  -2.10449875e+00
#   -2.10451155e+00  -2.10365605e+00  -2.10193225e+00  -2.09933974e+00
#   -2.09587771e+00  -2.09154493e+00  -2.08633977e+00  -2.08026021e+00
#   -2.07330385e+00  -2.06546791e+00  -2.05674925e+00  -2.04714441e+00
#   -2.03664959e+00  -2.02526068e+00  -2.01297330e+00  -1.99978282e+00
#   -1.98568438e+00  -1.97067293e+00  -1.95474324e+00  -1.93788998e+00
#   -1.92010771e+00  -1.90139096e+00  -1.88173425e+00  -1.86113217e+00
#   -1.83957938e+00  -1.81707073e+00  -1.79360124e+00  -1.76916624e+00
#   -1.74376139e+00  -1.71738274e+00  -1.69002685e+00  -1.66169079e+00
#   -1.63237228e+00  -1.60206974e+00  -1.57078239e+00  -1.53851028e+00
#   -1.50525446e+00  -1.47101700e+00  -1.43580107e+00  -1.39961108e+00
#   -1.36245275e+00  -1.32433313e+00  -1.28526079e+00  -1.24524580e+00
#   -1.20429987e+00  -1.16243639e+00  -1.11967053e+00  -1.07601925e+00
#   -1.03150139e+00  -9.86137709e-01  -9.39950924e-01  -8.92965721e-01
#   -8.45208786e-01  -7.96708804e-01  -7.47496456e-01  -6.97604398e-01
#   -6.47067228e-01  -5.95921442e-01  -5.44205379e-01  -4.91959143e-01
#   -4.39224526e-01  -3.86044902e-01  -3.32465126e-01  -2.78531404e-01
#   -2.24291164e-01  -1.69792914e-01  -1.15086085e-01  -6.02208730e-02
#   -5.24806922e-03   4.97811108e-02   1.04815206e-01   1.59802691e-01
#    2.14692155e-01   2.69432485e-01   3.23973042e-01   3.78263838e-01
#    4.32255707e-01   4.85900467e-01   5.39151075e-01   5.91961778e-01
#    6.44288246e-01   6.96087699e-01   7.47319020e-01   7.97942857e-01
#    8.47921709e-01   8.97220002e-01   9.45804146e-01   9.93642584e-01
#    1.04070582e+00   1.08696645e+00   1.13239916e+00   1.17698069e+00
#    1.22068989e+00   1.26350760e+00   1.30541669e+00   1.34640194e+00
#    1.38645004e+00   1.42554950e+00   1.46369056e+00   1.50086514e+00
#    1.53706676e+00   1.57229042e+00   1.60653255e+00   1.63979088e+00
#    1.67206441e+00   1.70335323e+00   1.73365851e+00   1.76298237e+00
#    1.79132777e+00   1.81869848e+00   1.84509894e+00   1.87053422e+00
#    1.89500989e+00   1.91853199e+00   1.94110695e+00   1.96274148e+00
#    1.98344256e+00   2.00321732e+00   2.02207304e+00   2.04001705e+00
#    2.05705668e+00   2.07319923e+00   2.08845194e+00   2.10282189e+00
#    2.11631600e+00   2.12894101e+00   2.14070341e+00   2.15160943e+00
#    2.16166500e+00   2.17087574e+00   2.17924691e+00   2.18678343e+00
#    2.19348984e+00   2.19937025e+00   2.20442840e+00   2.20866757e+00
#    2.21209063e+00   2.21469999e+00   2.21649760e+00   2.21748497e+00
#    2.21766314e+00   2.21703267e+00   2.21559367e+00   2.21334578e+00
#    2.21028816e+00   2.20641953e+00   2.20173811e+00   2.19624171e+00
#    2.18992767e+00   2.18279291e+00   2.17483389e+00   2.16604669e+00
#    2.15642697e+00   2.14597002e+00   2.13467075e+00   2.12252373e+00
#    2.10952320e+00   2.09566311e+00   2.08093711e+00   2.06533863e+00
#    2.04886089e+00   2.03149690e+00   2.01323955e+00   1.99408162e+00
#    1.97401583e+00   1.95303490e+00   1.93113156e+00   1.90829865e+00
#    1.88452914e+00   1.85981621e+00   1.83415332e+00   1.80753423e+00
#    1.77995315e+00   1.75140472e+00   1.72188416e+00   1.69138732e+00
#    1.65991077e+00   1.62745186e+00   1.59400886e+00   1.55958099e+00
#    1.52416854e+00   1.48777297e+00   1.45039701e+00   1.41204469e+00
#    1.37272151e+00   1.33243448e+00   1.29119223e+00   1.24900508e+00
#    1.20588513e+00   1.16184632e+00   1.11690450e+00   1.07107751e+00
#    1.02438522e+00   9.76849551e-01   9.28494548e-01   8.79346370e-01
#    8.29433314e-01   7.78785807e-01   7.27436393e-01   6.75419704e-01
#    6.22772410e-01   5.69533165e-01   5.15742536e-01   4.61442908e-01
#    4.06678392e-01   3.51494701e-01   2.95939028e-01   2.40059899e-01
#    1.83907027e-01   1.27531146e-01   7.09838377e-02   1.43173547e-02
#   -4.24155670e-02  -9.91618985e-02  -1.55868512e-01  -2.12482376e-01
#   -2.68950752e-01  -3.25221384e-01  -3.81242694e-01  -4.36963959e-01
#   -4.92335495e-01  -5.47308823e-01  -6.01836829e-01  -6.55873912e-01
#   -7.09376120e-01  -7.62301275e-01  -8.14609079e-01  -8.66261212e-01
#   -9.17221411e-01  -9.67455535e-01  -1.01693161e+00  -1.06561988e+00
#   -1.11349281e+00  -1.16052508e+00  -1.20669363e+00  -1.25197756e+00
#   -1.29635818e+00  -1.33981890e+00  -1.38234522e+00  -1.42392464e+00
#   -1.46454659e+00  -1.50420237e+00  -1.54288506e+00  -1.58058940e+00
#   -1.61731176e+00  -1.65304998e+00  -1.68780329e+00  -1.72157226e+00
#   -1.75435863e+00  -1.78616524e+00  -1.81699597e+00  -1.84685559e+00
#   -1.87574968e+00  -1.90368456e+00  -1.93066720e+00  -1.95670510e+00
#   -1.98180626e+00  -2.00597907e+00  -2.02923224e+00  -2.05157476e+00
#   -2.07301577e+00  -2.09356458e+00  -2.11323055e+00  -2.13202306e+00
#   -2.14995146e+00  -2.16702502e+00  -2.18325288e+00  -2.19864403e+00
#   -2.21320725e+00  -2.22695109e+00  -2.23988383e+00  -2.25201346e+00
#   -2.26334763e+00  -2.27389368e+00  -2.28365857e+00  -2.29264885e+00
#   -2.30087071e+00  -2.30832988e+00  -2.31503170e+00  -2.32098102e+00
#   -2.32618228e+00  -2.33063941e+00  -2.33435591e+00  -2.33733477e+00
#   -2.33957850e+00  -2.34108912e+00  -2.34186817e+00  -2.34191667e+00
#   -2.34123515e+00  -2.33982366e+00  -2.33768171e+00  -2.33480836e+00
#   -2.33120214e+00  -2.32686110e+00  -2.32178280e+00  -2.31596431e+00
#   -2.30940224e+00  -2.30209272e+00  -2.29403141e+00  -2.28521353e+00
#   -2.27563387e+00  -2.26528677e+00  -2.25416616e+00  -2.24226559e+00
#   -2.22957820e+00  -2.21609679e+00  -2.20181382e+00  -2.18672140e+00
#   -2.17081140e+00  -2.15407537e+00  -2.13650465e+00  -2.11809039e+00
#   -2.09882354e+00  -2.07869495e+00  -2.05769537e+00  -2.03581550e+00
#   -2.01304605e+00  -1.98937779e+00  -1.96480160e+00  -1.93930853e+00
#   -1.91288984e+00  -1.88553713e+00  -1.85724233e+00  -1.82799783e+00
#   -1.79779653e+00  -1.76663193e+00  -1.73449820e+00  -1.70139032e+00
#   -1.66730407e+00  -1.63223624e+00  -1.59618463e+00  -1.55914820e+00
#   -1.52112714e+00  -1.48212299e+00  -1.44213873e+00  -1.40117886e+00
#   -1.35924952e+00  -1.31635857e+00  -1.27251569e+00  -1.22773244e+00
#   -1.18202236e+00  -1.13540105e+00  -1.08788619e+00  -1.03949765e+00
#   -9.90257504e-01  -9.40190054e-01  -8.89321881e-01  -8.37681833e-01
#   -7.85301027e-01  -7.32212825e-01  -6.78452805e-01  -6.24058705e-01
#   -5.69070361e-01  -5.13529625e-01  -4.57480265e-01  -4.00967856e-01
#   -3.44039653e-01  -2.86744445e-01  -2.29132406e-01  -1.71254925e-01
#   -1.13164430e-01  -5.49141992e-02   3.44183329e-03   6.18492785e-02
#    1.20253500e-01   1.78599822e-01   2.36833742e-01   2.94901136e-01
#    3.52748469e-01   4.10322995e-01   4.67572954e-01   5.24447758e-01
#    5.80898170e-01   6.36876473e-01   6.92336619e-01   7.47234377e-01
#    8.01527453e-01   8.55175605e-01   9.08140737e-01   9.60386976e-01
#    1.01188074e+00   1.06259077e+00   1.11248819e+00   1.16154648e+00
#    1.20974150e+00   1.25705148e+00   1.30345697e+00   1.34894082e+00
#    1.39348811e+00   1.43708609e+00   1.47972411e+00   1.52139355e+00
#    1.56208771e+00   1.60180173e+00   1.64053248e+00   1.67827850e+00
#    1.71503983e+00   1.75081796e+00   1.78561570e+00   1.81943708e+00
#    1.85228726e+00   1.88417239e+00   1.91509957e+00   1.94507668e+00
#    1.97411235e+00   2.00221584e+00   2.02939696e+00   2.05566598e+00
#    2.08103357e+00   2.10551071e+00   2.12910862e+00   2.15183871e+00
#    2.17371250e+00   2.19474158e+00   2.21493753e+00   2.23431191e+00
#    2.25287619e+00   2.27064170e+00   2.28761961e+00   2.30382088e+00
#    2.31925626e+00   2.33393619e+00   2.34787085e+00   2.36107010e+00
#    2.37354346e+00   2.38530008e+00   2.39634874e+00   2.40669783e+00
#    2.41635534e+00   2.42532881e+00   2.43362537e+00   2.44125172e+00
#    2.44821409e+00   2.45451825e+00   2.46016951e+00   2.46517271e+00
#    2.46953221e+00   2.47325189e+00   2.47633515e+00   2.47878490e+00
#    2.48060355e+00   2.48179303e+00   2.48235477e+00   2.48228971e+00
#    2.48159830e+00   2.48028048e+00   2.47833570e+00   2.47576293e+00
#    2.47256064e+00   2.46872680e+00   2.46425891e+00   2.45915397e+00
#    2.45340850e+00   2.44701854e+00   2.43997967e+00   2.43228699e+00
#    2.42393513e+00   2.41491828e+00   2.40523017e+00   2.39486410e+00
#    2.38381291e+00   2.37206906e+00   2.35962457e+00   2.34647108e+00
#    2.33259984e+00   2.31800174e+00   2.30266732e+00   2.28658681e+00
#    2.26975010e+00   2.25214683e+00   2.23376637e+00   2.21459786e+00
#    2.19463026e+00   2.17385236e+00   2.15225283e+00   2.12982026e+00
#    2.10654318e+00   2.08241016e+00   2.05740981e+00   2.03153086e+00
#    2.00476220e+00   1.97709299e+00   1.94851264e+00   1.91901098e+00
#    1.88857826e+00   1.85720526e+00   1.82488336e+00   1.79160465e+00
#    1.75736200e+00   1.72214915e+00   1.68596082e+00   1.64879280e+00
#    1.61064206e+00   1.57150684e+00   1.53138676e+00   1.49028292e+00
#    1.44819803e+00   1.40513647e+00   1.36110441e+00   1.31610991e+00
#    1.27016302e+00   1.22327583e+00   1.17546259e+00   1.12673976e+00
#    1.07712607e+00   1.02664258e+00   9.75312737e-01   9.23162353e-01
#    8.70219666e-01   8.16515323e-01   7.62082359e-01   7.06956170e-01
#    6.51174467e-01   5.94777202e-01   5.37806494e-01   4.80306526e-01
#    4.22323428e-01   3.63905146e-01   3.05101296e-01   2.45962999e-01
#    1.86542706e-01   1.26894014e-01   6.70714621e-02   7.13032826e-03
#   -5.28735872e-02  -1.12884181e-01  -1.72845271e-01  -2.32700821e-01
#   -2.92395164e-01  -3.51873227e-01  -4.11080743e-01  -4.69964469e-01
#   -5.28472381e-01  -5.86553870e-01  -6.44159921e-01  -7.01243280e-01
#   -7.57758607e-01  -8.13662611e-01  -8.68914170e-01  -9.23474436e-01
#   -9.77306920e-01  -1.03037756e+00  -1.08265476e+00  -1.13410945e+00
#   -1.18471507e+00  -1.23444758e+00  -1.28328545e+00  -1.33120964e+00
#   -1.37820352e+00  -1.42425283e+00  -1.46934564e+00  -1.51347221e+00
#   -1.55662498e+00  -1.59879839e+00  -1.63998887e+00  -1.68019467e+00
#   -1.71941577e+00  -1.75765379e+00  -1.79491184e+00  -1.83119445e+00
#   -1.86650743e+00  -1.90085778e+00  -1.93425357e+00  -1.96670383e+00
#   -1.99821846e+00  -2.02880814e+00  -2.05848422e+00  -2.08725863e+00
#   -2.11514380e+00  -2.14215259e+00  -2.16829820e+00  -2.19359411e+00
#   -2.21805397e+00  -2.24169163e+00  -2.26452099e+00  -2.28655598e+00
#   -2.30781053e+00  -2.32829849e+00  -2.34803363e+00  -2.36702955e+00
#   -2.38529968e+00  -2.40285726e+00  -2.41971527e+00  -2.43588643e+00
#   -2.45138318e+00  -2.46621766e+00  -2.48040167e+00  -2.49394667e+00
#   -2.50686378e+00  -2.51916373e+00  -2.53085688e+00  -2.54195320e+00
#   -2.55246226e+00  -2.56239323e+00  -2.57175487e+00  -2.58055550e+00
#   -2.58880305e+00  -2.59650501e+00  -2.60366845e+00  -2.61029999e+00
#   -2.61640584e+00  -2.62199176e+00  -2.62706310e+00  -2.63162475e+00
#   -2.63568118e+00  -2.63923640e+00  -2.64229402e+00  -2.64485718e+00
#   -2.64692860e+00  -2.64851058e+00  -2.64960495e+00  -2.65021313e+00
#   -2.65033610e+00  -2.64997440e+00  -2.64912814e+00  -2.64779700e+00
#   -2.64598022e+00  -2.64367661e+00  -2.64088456e+00  -2.63760199e+00
#   -2.63382644e+00  -2.62955499e+00  -2.62478428e+00  -2.61951055e+00
#   -2.61372958e+00  -2.60743674e+00  -2.60062698e+00  -2.59329480e+00
#   -2.58543429e+00  -2.57703912e+00  -2.56810253e+00  -2.55861735e+00
#   -2.54857599e+00  -2.53797046e+00  -2.52679234e+00  -2.51503283e+00
#   -2.50268273e+00  -2.48973244e+00  -2.47617198e+00  -2.46199102e+00
#   -2.44717882e+00  -2.43172434e+00  -2.41561617e+00  -2.39884258e+00
#   -2.38139155e+00  -2.36325073e+00  -2.34440755e+00  -2.32484915e+00
#   -2.30456248e+00  -2.28353427e+00  -2.26175111e+00  -2.23919944e+00
#   -2.21586562e+00  -2.19173594e+00  -2.16679669e+00  -2.14103419e+00
#   -2.11443486e+00  -2.08698525e+00  -2.05867212e+00  -2.02948247e+00
#   -1.99940368e+00  -1.96842348e+00  -1.93653013e+00  -1.90371242e+00
#   -1.86995980e+00  -1.83526246e+00  -1.79961141e+00  -1.76299859e+00
#   -1.72541697e+00  -1.68686067e+00  -1.64732501e+00  -1.60680669e+00
#   -1.56530385e+00  -1.52281619e+00  -1.47934509e+00  -1.43489372e+00
#   -1.38946711e+00  -1.34307231e+00  -1.29571844e+00  -1.24741681e+00
#   -1.19818096e+00  -1.14802681e+00  -1.09697265e+00  -1.04503926e+00
#   -9.92249900e-01  -9.38630360e-01  -8.84208987e-01  -8.29016667e-01
#   -7.73086813e-01  -7.16455332e-01  -6.59160568e-01  -6.01243237e-01
#   -5.42746333e-01  -4.83715026e-01  -4.24196533e-01  -3.64239977e-01
#   -3.03896233e-01  -2.43217744e-01  -1.82258346e-01  -1.21073053e-01
#   -5.97178551e-02   1.75050821e-03   6.32747773e-02   1.24797407e-01
#    1.86260804e-01   2.47607570e-01   3.08780737e-01   3.69724003e-01
#    4.30381966e-01   4.90700343e-01   5.50626186e-01   6.10108081e-01
#    6.69096342e-01   7.27543180e-01   7.85402865e-01   8.42631868e-01
#    8.99188981e-01   9.55035426e-01   1.01013494e+00   1.06445383e+00
#    1.11796106e+00   1.17062822e+00   1.22242959e+00   1.27334210e+00
#    1.32334534e+00   1.37242147e+00   1.42055525e+00   1.46773387e+00
#    1.51394697e+00   1.55918649e+00   1.60344662e+00   1.64672366e+00
#    1.68901593e+00   1.73032365e+00   1.77064887e+00   1.80999525e+00
#    1.84836807e+00   1.88577401e+00   1.92222109e+00   1.95771853e+00
#    1.99227664e+00   2.02590675e+00   2.05862104e+00   2.09043249e+00
#    2.12135476e+00   2.15140212e+00   2.18058933e+00   2.20893160e+00
#    2.23644449e+00   2.26314382e+00   2.28904566e+00   2.31416619e+00
#    2.33852174e+00   2.36212864e+00   2.38500324e+00   2.40716185e+00
#    2.42862068e+00   2.44939581e+00   2.46950319e+00   2.48895858e+00
#    2.50777753e+00   2.52597535e+00   2.54356710e+00   2.56056759e+00
#    2.57699133e+00   2.59285254e+00   2.60816511e+00   2.62294264e+00
#    2.63719838e+00   2.65094528e+00   2.66419590e+00   2.67696252e+00
#    2.68925703e+00   2.70109098e+00   2.71247560e+00   2.72342174e+00
#    2.73393993e+00   2.74404032e+00   2.75373276e+00   2.76302672e+00
#    2.77193136e+00   2.78045547e+00   2.78860754e+00   2.79639571e+00
#    2.80382779e+00   2.81091128e+00   2.81765335e+00   2.82406085e+00
#    2.83014033e+00   2.83589803e+00   2.84133987e+00   2.84647148e+00
#    2.85129819e+00   2.85582503e+00   2.86005676e+00   2.86399782e+00
#    2.86765240e+00   2.87102437e+00   2.87411736e+00   2.87693469e+00
#    2.87947944e+00   2.88175440e+00   2.88376209e+00   2.88550478e+00
#    2.88698445e+00   2.88820284e+00   2.88916143e+00   2.88986142e+00
#    2.89030377e+00   2.89048918e+00   2.89041809e+00   2.89009067e+00
#    2.88950687e+00   2.88866636e+00   2.88756855e+00   2.88621260e+00
#    2.88459743e+00   2.88272168e+00   2.88058376e+00   2.87818178e+00
#    2.87551364e+00   2.87257694e+00   2.86936904e+00   2.86588703e+00
#    2.86212773e+00   2.85808769e+00   2.85376321e+00   2.84915030e+00
#    2.84424470e+00   2.83904186e+00   2.83353697e+00   2.82772493e+00
#    2.82160035e+00   2.81515756e+00   2.80839058e+00   2.80129316e+00
#    2.79385873e+00   2.78608044e+00   2.77795111e+00   2.76946326e+00
#    2.76060912e+00   2.75138058e+00   2.74176923e+00   2.73176632e+00
#    2.72136280e+00   2.71054929e+00   2.69931607e+00   2.68765312e+00
#    2.67555005e+00   2.66299617e+00   2.64998047e+00   2.63649157e+00
#    2.62251779e+00   2.60804713e+00   2.59306724e+00   2.57756546e+00
#    2.56152882e+00   2.54494405e+00   2.52779754e+00   2.51007543e+00
#    2.49176355e+00   2.47284746e+00   2.45331247e+00   2.43314366e+00]
# [  0.00000000e+00  -9.08391924e-02  -1.81678385e-01  -2.72551793e-01
#   -3.63493391e-01  -4.54536687e-01  -5.45714486e-01  -6.37058667e-01
#   -7.28599942e-01  -8.20367621e-01  -9.12389367e-01  -1.00469095e+00
#   -1.09729600e+00  -1.19022574e+00  -1.28349870e+00  -1.37713052e+00
#   -1.47113356e+00  -1.56551673e+00  -1.66028512e+00  -1.75543973e+00
#   -1.85097719e+00  -1.94688944e+00  -2.04316341e+00  -2.13978075e+00
#   -2.23671749e+00  -2.33394378e+00  -2.43142355e+00  -2.52911428e+00
#   -2.62696666e+00  -2.72492442e+00  -2.82292401e+00  -2.92089446e+00
#   -3.01875715e+00  -3.11642567e+00  -3.21380574e+00  -3.31079513e+00
#   -3.40728362e+00  -3.50315307e+00  -3.59827750e+00  -3.69252325e+00
#   -3.78574923e+00  -3.87780721e+00  -3.96854217e+00  -4.05779280e+00
#   -4.14539201e+00  -4.23116755e+00  -4.31494272e+00  -4.39653712e+00
#   -4.47576752e+00  -4.55244879e+00  -4.62639488e+00  -4.69741988e+00
#   -4.76533910e+00  -4.82997027e+00  -4.89113465e+00  -4.94865831e+00
#   -5.00237327e+00  -5.05211875e+00  -5.09774233e+00  -5.13910114e+00
#   -5.17606296e+00  -5.20850726e+00  -5.23632618e+00  -5.25942548e+00
#   -5.27772526e+00  -5.29116073e+00  -5.29968274e+00  -5.30325825e+00
#   -5.30187066e+00  -5.29551998e+00  -5.28422290e+00  -5.26801267e+00
#   -5.24693889e+00  -5.22106715e+00  -5.19047849e+00  -5.15526882e+00
#   -5.11554814e+00  -5.07143971e+00  -5.02307908e+00  -4.97061306e+00
#   -4.91419861e+00  -4.85400165e+00  -4.79019588e+00  -4.72296151e+00
#   -4.65248400e+00  -4.57895280e+00  -4.50256010e+00  -4.42349964e+00
#   -4.34196545e+00  -4.25815080e+00  -4.17224708e+00  -4.08444279e+00
#   -3.99492262e+00  -3.90386661e+00  -3.81144935e+00  -3.71783935e+00
#   -3.62319838e+00  -3.52768102e+00  -3.43143424e+00  -3.33459703e+00
#   -3.23730018e+00  -3.13966606e+00  -3.04180858e+00  -2.94383309e+00
#   -2.84583644e+00  -2.74790702e+00  -2.65012492e+00  -2.55256207e+00
#   -2.45528245e+00  -2.35834235e+00  -2.26179060e+00  -2.16566887e+00
#   -2.07001195e+00  -1.97484811e+00  -1.88019937e+00  -1.78608185e+00
#   -1.69250612e+00  -1.59947748e+00  -1.50699633e+00  -1.41505847e+00
#   -1.32365542e+00  -1.23277473e+00  -1.14240028e+00  -1.05251257e+00
#   -9.63089017e-01  -8.74104193e-01  -7.85530121e-01  -6.97336512e-01
#   -6.09491017e-01  -5.21959455e-01  -4.34706046e-01  -3.47693631e-01
#   -2.60883882e-01  -1.74237511e-01  -8.77144713e-02  -1.27415760e-03
#    8.51244028e-02   1.71522356e-01   2.57960832e-01   3.44480753e-01
#    4.31122643e-01   5.17926437e-01   6.04931286e-01   6.92175355e-01
#    7.79695626e-01   8.67527687e-01   9.55705520e-01   1.04426128e+00
#    1.13322506e+00   1.22262467e+00   1.31248540e+00   1.40282971e+00
#    1.49367705e+00   1.58504353e+00   1.67694166e+00   1.76938007e+00
#    1.86236318e+00   1.95589093e+00   2.04995847e+00   2.14455580e+00
#    2.23966748e+00   2.33527233e+00   2.43134306e+00   2.52784599e+00
#    2.62474070e+00   2.72197978e+00   2.81950849e+00   2.91726451e+00
#    3.01517768e+00   3.11316982e+00   3.21115446e+00   3.30903677e+00
#    3.40671339e+00   3.50407240e+00   3.60099331e+00   3.69734711e+00
#    3.79299640e+00   3.88779558e+00   3.98159114e+00   4.07422196e+00
#    4.16551980e+00   4.25530982e+00   4.34341117e+00   4.42963769e+00
#    4.51379873e+00   4.59570000e+00   4.67514458e+00   4.75193388e+00
#    4.82586883e+00   4.89675102e+00   4.96438391e+00   5.02857417e+00
#    5.08913288e+00   5.14587696e+00   5.19863040e+00   5.24722564e+00
#    5.29150483e+00   5.33132104e+00   5.36653952e+00   5.39703873e+00
#    5.42271143e+00   5.44346557e+00   5.45922512e+00   5.46993072e+00
#    5.47554030e+00   5.47602940e+00   5.47139154e+00   5.46163822e+00
#    5.44679897e+00   5.42692108e+00   5.40206929e+00   5.37232528e+00
#    5.33778702e+00   5.29856800e+00   5.25479633e+00   5.20661373e+00
#    5.15417441e+00   5.09764389e+00   5.03719771e+00   4.97302013e+00
#    4.90530275e+00   4.83424318e+00   4.76004359e+00   4.68290940e+00
#    4.60304789e+00   4.52066694e+00   4.43597374e+00   4.34917362e+00
#    4.26046896e+00   4.17005811e+00   4.07813452e+00   3.98488581e+00
#    3.89049310e+00   3.79513031e+00   3.69896361e+00   3.60215100e+00
#    3.50484188e+00   3.40717683e+00   3.30928739e+00   3.21129597e+00
#    3.11331579e+00   3.01545091e+00   2.91779634e+00   2.82043816e+00
#    2.72345371e+00   2.62691183e+00   2.53087310e+00   2.43539016e+00
#    2.34050801e+00   2.24626432e+00   2.15268980e+00   2.05980852e+00
#    1.96763830e+00   1.87619104e+00   1.78547307e+00   1.69548550e+00
#    1.60622459e+00   1.51768204e+00   1.42984533e+00   1.34269802e+00
#    1.25622010e+00   1.17038820e+00   1.08517594e+00   1.00055411e+00
#    9.16491017e-01   8.32952644e-01   7.49902917e-01   6.67303905e-01
#    5.85116029e-01   5.03298259e-01   4.21808294e-01   3.40602742e-01
#    2.59637291e-01   1.78866871e-01   9.82458106e-02   1.77279935e-02
#   -6.27329952e-02  -1.43183720e-01  -2.23670752e-01  -3.04240520e-01
#   -3.84939170e-01  -4.65812415e-01  -5.46905389e-01  -6.28262494e-01
#   -7.09927242e-01  -7.91942094e-01  -8.74348294e-01  -9.57185692e-01
#   -1.04049256e+00  -1.12430541e+00  -1.20865877e+00  -1.29358500e+00
#   -1.37911405e+00  -1.46527326e+00  -1.55208705e+00  -1.63957674e+00
#   -1.72776023e+00  -1.81665174e+00  -1.90626150e+00  -1.99659549e+00
#   -2.08765507e+00  -2.17943670e+00  -2.27193158e+00  -2.36512533e+00
#   -2.45899766e+00  -2.55352198e+00  -2.64866510e+00  -2.74438685e+00
#   -2.84063980e+00  -2.93736888e+00  -3.03451111e+00  -3.13199529e+00
#   -3.22974175e+00  -3.32766215e+00  -3.42565922e+00  -3.52362667e+00
#   -3.62144907e+00  -3.71900182e+00  -3.81615116e+00  -3.91275426e+00
#   -4.00865942e+00  -4.10370627e+00  -4.19772617e+00  -4.29054257e+00
#   -4.38197161e+00  -4.47182267e+00  -4.55989917e+00  -4.64599931e+00
#   -4.72991705e+00  -4.81144309e+00  -4.89036598e+00  -4.96647330e+00
#   -5.03955293e+00  -5.10939434e+00  -5.17579000e+00  -5.23853674e+00
#   -5.29743725e+00  -5.35230145e+00  -5.40294798e+00  -5.44920560e+00
#   -5.49091451e+00  -5.52792774e+00  -5.56011231e+00  -5.58735041e+00
#   -5.60954043e+00  -5.62659784e+00  -5.63845602e+00  -5.64506683e+00
#   -5.64640114e+00  -5.64244911e+00  -5.63322033e+00  -5.61874384e+00
#   -5.59906790e+00  -5.57425962e+00  -5.54440448e+00  -5.50960559e+00
#   -5.46998292e+00  -5.42567225e+00  -5.37682417e+00  -5.32360281e+00
#   -5.26618453e+00  -5.20475661e+00  -5.13951574e+00  -5.07066660e+00
#   -4.99842030e+00  -4.92299292e+00  -4.84460400e+00  -4.76347508e+00
#   -4.67982824e+00  -4.59388482e+00  -4.50586407e+00  -4.41598195e+00
#   -4.32445005e+00  -4.23147456e+00  -4.13725536e+00  -4.04198521e+00
#   -3.94584907e+00  -3.84902354e+00  -3.75167632e+00  -3.65396589e+00
#   -3.55604119e+00  -3.45804148e+00  -3.36009620e+00  -3.26232497e+00
#   -3.16483764e+00  -3.06773441e+00  -2.97110597e+00  -2.87503377e+00
#   -2.77959027e+00  -2.68483921e+00  -2.59083597e+00  -2.49762790e+00
#   -2.40525471e+00  -2.31374879e+00  -2.22313566e+00  -2.13343434e+00
#   -2.04465768e+00  -1.95681280e+00  -1.86990145e+00  -1.78392036e+00
#   -1.69886157e+00  -1.61471284e+00  -1.53145790e+00  -1.44907679e+00
#   -1.36754618e+00  -1.28683960e+00  -1.20692776e+00  -1.12777875e+00
#   -1.04935832e+00  -9.71630072e-01  -8.94555668e-01  -8.18095040e-01
#   -7.42206560e-01  -6.66847208e-01  -5.91972737e-01  -5.17537816e-01
#   -4.43496168e-01  -3.69800703e-01  -2.96403638e-01  -2.23256617e-01
#   -1.50310813e-01  -7.75170399e-02  -4.82585173e-03   6.78123609e-02
#    1.40447274e-01   2.13128536e-01   2.85905672e-01   3.58827994e-01
#    4.31944499e-01   5.05303775e-01   5.78953898e-01   6.52942325e-01
#    7.27315788e-01   8.02120174e-01   8.77400404e-01   9.53200300e-01
#    1.02956245e+00   1.10652806e+00   1.18413679e+00   1.26242660e+00
#    1.34143354e+00   1.42119160e+00   1.50173246e+00   1.58308531e+00
#    1.66527659e+00   1.74832976e+00   1.83226502e+00   1.91709906e+00
#    2.00284476e+00   2.08951086e+00   2.17710168e+00   2.26561678e+00
#    2.35505058e+00   2.44539207e+00   2.53662441e+00   2.62872454e+00
#    2.72166287e+00   2.81540286e+00   2.90990066e+00   3.00510476e+00
#    3.10095560e+00   3.19738528e+00   3.29431723e+00   3.39166590e+00
#    3.48933652e+00   3.58722489e+00   3.68521719e+00   3.78318991e+00
#    3.88100975e+00   3.97853368e+00   4.07560899e+00   4.17207351e+00
#    4.26775586e+00   4.36247580e+00   4.45604475e+00   4.54826626e+00
#    4.63893681e+00   4.72784649e+00   4.81477997e+00   4.89951745e+00
#    4.98183581e+00   5.06150977e+00   5.13831321e+00   5.21202053e+00
#    5.28240810e+00   5.34925573e+00   5.41234824e+00   5.47147699e+00
#    5.52644144e+00   5.57705075e+00   5.62312522e+00   5.66449786e+00
#    5.70101571e+00   5.73254119e+00   5.75895331e+00   5.78014878e+00
#    5.79604289e+00   5.80657039e+00   5.81168609e+00   5.81136532e+00
#    5.80560423e+00   5.79441987e+00   5.77785015e+00   5.75595353e+00
#    5.72880857e+00   5.69651331e+00   5.65918446e+00   5.61695646e+00
#    5.56998035e+00   5.51842254e+00   5.46246346e+00   5.40229613e+00
#    5.33812459e+00   5.27016236e+00   5.19863079e+00   5.12375747e+00
#    5.04577451e+00   4.96491705e+00   4.88142157e+00   4.79552448e+00
#    4.70746062e+00   4.61746194e+00   4.52575624e+00   4.43256602e+00
#    4.33810745e+00   4.24258945e+00   4.14621289e+00   4.04916993e+00
#    3.95164345e+00   3.85380658e+00   3.75582240e+00   3.65784371e+00
#    3.56001288e+00   3.46246179e+00   3.36531192e+00   3.26867443e+00
#    3.17265031e+00   3.07733067e+00   2.98279699e+00   2.88912143e+00
#    2.79636721e+00   2.70458896e+00   2.61383315e+00   2.52413847e+00
#    2.43553625e+00   2.34805092e+00   2.26170038e+00   2.17649644e+00
#    2.09244521e+00   2.00954751e+00   1.92779926e+00   1.84719183e+00
#    1.76771239e+00   1.68934426e+00   1.61206723e+00   1.53585786e+00
#    1.46068973e+00   1.38653377e+00   1.31335846e+00   1.24113006e+00
#    1.16981285e+00   1.09936933e+00   1.02976038e+00   9.60945441e-01
#    8.92882676e-01   8.25529108e-01   7.58840750e-01   6.92772728e-01
#    6.27279385e-01   5.62314385e-01   4.97830803e-01   4.33781203e-01
#    3.70117720e-01   3.06792124e-01   2.43755887e-01   1.80960237e-01
#    1.18356215e-01   5.58947262e-02  -6.47341508e-03  -6.87974379e-02
#   -1.31126571e-01  -1.93510001e-01  -2.55996827e-01  -3.18636018e-01
#   -3.81476369e-01  -4.44566453e-01  -5.07954574e-01  -5.71688711e-01
#   -6.35816466e-01  -7.00385002e-01  -7.65440977e-01  -8.31030469e-01
#   -8.97198906e-01  -9.63990970e-01  -1.03145051e+00  -1.09962044e+00
#   -1.16854262e+00  -1.23825773e+00  -1.30880515e+00  -1.38022282e+00
#   -1.45254704e+00  -1.52581235e+00  -1.60005130e+00  -1.67529429e+00
#   -1.75156930e+00  -1.82890172e+00  -1.90731407e+00  -1.98682572e+00
#   -2.06745264e+00  -2.14920707e+00  -2.23209726e+00  -2.31612705e+00
#   -2.40129562e+00  -2.48759707e+00  -2.57502006e+00  -2.66354744e+00
#   -2.75315583e+00  -2.84381524e+00  -2.93548866e+00  -3.02813167e+00
#   -3.12169201e+00  -3.21610919e+00  -3.31131416e+00  -3.40722888e+00
#   -3.50376605e+00  -3.60082876e+00  -3.69831025e+00  -3.79609371e+00
#   -3.89405209e+00  -3.99204802e+00  -4.08993378e+00  -4.18755136e+00
#   -4.28473260e+00  -4.38129944e+00  -4.47706421e+00  -4.57183016e+00
#   -4.66539194e+00  -4.75753634e+00  -4.84804304e+00  -4.93668555e+00
#   -5.02323225e+00  -5.10744752e+00  -5.18909300e+00  -5.26792897e+00
#   -5.34371577e+00  -5.41621535e+00  -5.48519286e+00  -5.55041828e+00
#   -5.61166813e+00  -5.66872712e+00  -5.72138987e+00  -5.76946251e+00
#   -5.81276435e+00  -5.85112938e+00  -5.88440771e+00  -5.91246691e+00
#   -5.93519325e+00  -5.95249272e+00  -5.96429193e+00  -5.97053886e+00
#   -5.97120338e+00  -5.96627763e+00  -5.95577610e+00  -5.93973564e+00
#   -5.91821516e+00  -5.89129518e+00  -5.85907719e+00  -5.82168277e+00
#   -5.77925263e+00  -5.73194539e+00  -5.67993626e+00  -5.62341561e+00
#   -5.56258740e+00  -5.49766756e+00  -5.42888223e+00  -5.35646607e+00
#   -5.28066045e+00  -5.20171173e+00  -5.11986946e+00  -5.03538473e+00
#   -4.94850855e+00  -4.85949024e+00  -4.76857604e+00  -4.67600771e+00
#   -4.58202136e+00  -4.48684626e+00  -4.39070393e+00  -4.29380728e+00
#   -4.19635986e+00  -4.09855530e+00  -4.00057687e+00  -3.90259708e+00
#   -3.80477751e+00  -3.70726867e+00  -3.61020994e+00  -3.51372971e+00
#   -3.41794543e+00  -3.32296391e+00  -3.22888150e+00  -3.13578449e+00
#   -3.04374944e+00  -2.95284355e+00  -2.86312513e+00  -2.77464401e+00
#   -2.68744198e+00  -2.60155330e+00  -2.51700510e+00  -2.43381786e+00
#   -2.35200587e+00  -2.27157767e+00  -2.19253645e+00  -2.11488048e+00
#   -2.03860351e+00  -1.96369513e+00  -1.89014114e+00  -1.81792389e+00
#   -1.74702259e+00  -1.67741361e+00  -1.60907077e+00  -1.54196557e+00
#   -1.47606749e+00  -1.41134414e+00  -1.34776152e+00  -1.28528420e+00
#   -1.22387547e+00  -1.16349750e+00  -1.10411152e+00  -1.04567792e+00
#   -9.88156356e-01  -9.31505881e-01  -8.75685027e-01  -8.20651894e-01
#   -7.66364217e-01  -7.12779439e-01  -6.59854763e-01  -6.07547206e-01
#   -5.55813641e-01  -5.04610832e-01  -4.53895470e-01  -4.03624194e-01
#   -3.53753618e-01  -3.04240345e-01  -2.55040986e-01  -2.06112162e-01
#   -1.57410525e-01  -1.08892753e-01  -6.05155583e-02  -1.22356925e-02
#    3.59900560e-02   8.42048601e-02   1.32451854e-01   1.80774133e-01
#    2.29214754e-01   2.77816737e-01   3.26623058e-01   3.75676654e-01
#    4.25020413e-01   4.74697171e-01   5.24749703e-01   5.75220711e-01
#    6.26152814e-01   6.77588525e-01   7.29570234e-01   7.82140180e-01
#    8.35340421e-01   8.89212801e-01   9.43798903e-01   9.99140005e-01
#    1.05527702e+00   1.11225045e+00   1.17010029e+00   1.22886596e+00
#    1.28858622e+00   1.34929907e+00   1.41104163e+00   1.47385003e+00
#    1.53775926e+00   1.60280305e+00   1.66901366e+00   1.73642175e+00
#    1.80505618e+00   1.87494378e+00   1.94610912e+00   2.01857432e+00
#    2.09235872e+00   2.16747866e+00   2.24394715e+00   2.32177357e+00
#    2.40096330e+00   2.48151745e+00   2.56343240e+00   2.64669947e+00
#    2.73130451e+00   2.81722747e+00   2.90444201e+00   2.99291504e+00
#    3.08260627e+00   3.17346782e+00   3.26544374e+00   3.35846959e+00
#    3.45247205e+00   3.54736848e+00   3.64306657e+00   3.73946403e+00
#    3.83644825e+00   3.93389607e+00   4.03167360e+00   4.12963608e+00
#    4.22762786e+00   4.32548239e+00   4.42302244e+00   4.52006023e+00
#    4.61639787e+00   4.71182776e+00   4.80613321e+00   4.89908912e+00
#    4.99046288e+00   5.08001528e+00   5.16750162e+00   5.25267299e+00
#    5.33527754e+00   5.41506199e+00   5.49177315e+00   5.56515958e+00
#    5.63497329e+00   5.70097152e+00   5.76291853e+00   5.82058742e+00
#    5.87376191e+00   5.92223814e+00   5.96582640e+00   6.00435273e+00
#    6.03766051e+00   6.06561183e+00   6.08808884e+00   6.10499479e+00
#    6.11625505e+00   6.12181782e+00   6.12165467e+00   6.11576095e+00
#    6.10415582e+00   6.08688224e+00   6.06400660e+00   6.03561821e+00
#    6.00182857e+00   5.96277041e+00   5.91859655e+00   5.86947866e+00
#    5.81560576e+00   5.75718263e+00   5.69442814e+00   5.62757346e+00
#    5.55686020e+00   5.48253854e+00   5.40486532e+00   5.32410212e+00
#    5.24051347e+00   5.15436498e+00   5.06592166e+00   4.97544627e+00
#    4.88319778e+00   4.78942998e+00   4.69439023e+00   4.59831826e+00
#    4.50144525e+00   4.40399292e+00   4.30617285e+00   4.20818591e+00
#    4.11022181e+00   4.01245881e+00   3.91506355e+00   3.81819091e+00
#    3.72198412e+00   3.62657482e+00   3.53208326e+00   3.43861862e+00
#    3.34627925e+00   3.25515312e+00   3.16531823e+00   3.07684300e+00
#    2.98978682e+00   2.90420046e+00   2.82012665e+00   2.73760049e+00
#    2.65665005e+00   2.57729676e+00   2.49955597e+00   2.42343737e+00
#    2.34894547e+00   2.27608005e+00   2.20483651e+00   2.13520636e+00
#    2.06717751e+00   2.00073468e+00   1.93585970e+00   1.87253185e+00
#    1.81072812e+00   1.75042350e+00   1.69159122e+00   1.63420297e+00
#    1.57822914e+00   1.52363898e+00   1.47040083e+00   1.41848220e+00
#    1.36784999e+00   1.31847059e+00   1.27031002e+00   1.22333400e+00
#    1.17750807e+00   1.13279771e+00   1.08916835e+00   1.04658546e+00
#    1.00501466e+00   9.64421689e-01   9.24772510e-01   8.86033320e-01
#    8.48170592e-01   8.11151098e-01   7.74941931e-01   7.39510524e-01
#    7.04824660e-01   6.70852486e-01   6.37562517e-01   6.04923638e-01
#    5.72905107e-01   5.41476552e-01   5.10607965e-01   4.80269702e-01
#    4.50432469e-01   4.21067313e-01   3.92145617e-01   3.63639082e-01
#    3.35519715e-01   3.07759818e-01   2.80331968e-01   2.53209007e-01
#    2.26364021e-01   1.99770323e-01   1.73401440e-01   1.47231088e-01
#    1.21233160e-01   9.53817048e-02   6.96509060e-02   4.40150661e-02
#    1.84485854e-02  -7.07405733e-03  -3.25783239e-02  -5.80896369e-02
#   -8.36333988e-02  -1.09235012e-01  -1.34919898e-01  -1.60713516e-01
#   -1.86641385e-01  -2.12729098e-01  -2.39002346e-01  -2.65486934e-01
#   -2.92208798e-01  -3.19194024e-01  -3.46468867e-01  -3.74059766e-01
#   -4.01993361e-01  -4.30296508e-01  -4.58996295e-01  -4.88120055e-01
#   -5.17695383e-01  -5.47750141e-01  -5.78312478e-01  -6.09410833e-01
#   -6.41073948e-01  -6.73330874e-01  -7.06210973e-01  -7.39743928e-01
#   -7.73959740e-01  -8.08888729e-01  -8.44561527e-01  -8.81009080e-01
#   -9.18262631e-01  -9.56353710e-01  -9.95314121e-01  -1.03517592e+00
#   -1.07597138e+00  -1.11773299e+00  -1.16049338e+00  -1.20428533e+00
#   -1.24914166e+00  -1.29509525e+00  -1.34217891e+00  -1.39042536e+00
#   -1.43986714e+00  -1.49053651e+00  -1.54246536e+00  -1.59568511e+00
#   -1.65022659e+00  -1.70611990e+00  -1.76339428e+00  -1.82207793e+00
#   -1.88219785e+00  -1.94377967e+00  -2.00684742e+00  -2.07142330e+00]

# %% [markdown]
# ### 1.f Leap-Frog Plots
#
# Using the leap-frog data generated in problem 1.e, remake the plots you have made earlier in this problem showing both the Runge-Kutta result and the Leap-Frog results simultaneously on each plot.
#
# You shouldn't have to re-generate any of the data.

# %%
plt.plot(times, thetas
         , label='RK')
plt.plot(times, thetas_lf
         , label='LF')
plt.plot(times, omegas
         , label='RK_w')
plt.plot(times, omegas_lf
         , label='LF_w')
plt.title("Simple Pendulum: RK vs LF")
plt.xlabel('time')
plt.ylabel('Measurements [mks]')
plt.legend()
plt.show()

# %%
plt.plot(thetas, mass*ell**2*omegas
         , label='RK')
plt.plot(thetas_lf, mass*ell**2*omegas_lf
         , label='LF')
plt.title("Simple Pendulum: Phase Space")
plt.xlabel('angle')
plt.ylabel('momentum')
plt.legend()
plt.show()

# %%
m = 1.0

energies_lf = .5*m*ell**2*omegas_lf**2 + m*g*ell*(1-np.cos(thetas_lf))
Energy =  .5*m*ell**2*omegas**2 + m*g*ell*(1-np.cos(thetas))
plt.plot(times, Energy
         , label='RK')
plt.plot(times, energies_lf
         , label='LF')
plt.title("Simple Pendulum: Energy, RK vs LF")
plt.xlabel('Time')
plt.ylabel('Energy')
plt.show()

# %% [markdown]
# ### 1.g Leap-Frog Time Reversal Symmetry
#
# Re-do problem 1.d using Leap-Frog. Plot the amplitude as a function of time for:
# 1. the original Runge-Kutta data (from 1.a)
# 2. the time-reversed Runge-Kutta data (from 1.d)
# 3. the original Leap-Frog data (from 1.3)
# 4. the time-reversed Leap-Frog data

# %%
theta_0 = 2.43314366# FILL THIS IN (use the  "_lf" data)
omega_0 = -2.07142330# FILL THIS IN (use the  "_lf" data)
dt = -.01# FILL THIS IN
t_final = 10
# old set of time samples, you want tpoints to be the "reverse" of this
tpoints = np.arange(t_final, 0,dt)# FILL THIS IN, we want it time-reversed

back_times, back_thetas_lf, back_omegas_lf = time_and_angles_leapfrog()

# CLEAN UP
# (Return global values back to their original values)
dt = 0.01  
tpoints = np.arange(0, t_final, abs(dt))

# Define a small offset so that you can see lines
# that would otherwise be overlapping
OFFSET = 0.5

# Compare plots
plt.plot(times, thetas, label='Running forward from initial condition')
plt.plot(back_times, back_thetas, label='Running backward from final condition')
plt.plot(times, thetas_lf + OFFSET, label='LF: Running forward from initial condition')
plt.plot(back_times, back_thetas_lf, label='LF: Running backward from final condition')
plt.title("Simple Pendulum in Runge-Kutta: Time Reversal")
plt.xlabel('time')
plt.ylabel('Theta [rad]')
plt.legend() 
plt.show()

# %% [markdown]
# ## Problem 2: Not-So Simple Pendula
#
# Using the same initial conditions as in Problem 1, copy and paste ("<a href="http://knowyourmeme.com/memes/copypasta">copy-pasta</a>") your code from Problem 1.e and adapt it to a not-so simple pendulum.
#
# ### Problem 2.a
#
# Include the following forces:
# * Damping force, with damping coefficient `q_damp`
# * Driving force with amplitude `F_drive` and frequency `omega_drive`
# * Drag force with air density `rho`, drac coefficient `C_drag` and some `area`
#
# Make sure that the forces are pointed in the right direction! (If your code isn't stable because your velocity gets huge, this might be way.)
#
# Set `t_final` to 20 seconds. Set `q_damp = 0.1`, `F_drive = 1.4`, and `omega_drive = 1.0`. Assume that the bob has radius .1 (what's the area?), and that the drag coefficient is 1.0. What's a reasonable value for the density of air? (What units are we using?)
#
# Plot the results.

# %%
t_final = 20 # FILL THIS IN
dt = .01
tpoints = np.arange(0, t_final, dt)

# FILL IN THE PARAMETERS OF THE NEW FORCES HERE

# Redefine h to include other forces
def h(theta,omega,t):
    """d(omega)/dt, in the presence of other stuff"""
    SHO = 0 # FILL IN Simple Harmonic Oscillator here
    friction = 0 # FILL IN friction force
    drive = 0 # FILL IN driving force
    drag = 0 # FILL IN drag force
    return SHO + friction + drive + drag

times, thetas_real, omegas_real = time_and_angles_leapfrog()
plt.plot(times, thetas_real)
plt.title("Not So Simple Pendulum")
plt.xlabel('time')
plt.ylabel('Angle')
plt.show()

# %% [markdown]
# ### Problem 2.b
#
# Set `t_final` to 50 seconds and `dt` to 0.001. Turn off the driving force. Approximately how long does it take for the amplitude of the oscillation to decrease to 0.25 radians?

# %%
# FILL THIS IN

# %% [markdown]
# ### Problem 2.c
#
# Plot the trajectory in Problem 2.b in phase space.

# %%
## FILL THIS IN

# %% [markdown]
# ## Addendum: How to animate
#
# In class we brought up the question of how to get inline animations in Jupyter. The answer turns out to be a little subtle.
#
# The key is to use
# `%matplotlib notebook`
#
# See:
# http://stackoverflow.com/questions/43445103/inline-animations-in-jupyter/43447370
#
# Note: this affects all of the cells, so you might want to use
# `%matplotlib inline`
# for other cells without animation. (Otherwise they look weird to me)

# %%
# EXAMPLE:

# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)

# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

HTML(anim.to_html5_video())
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-71ca5f8f4ee9> in <module>()
#      32                                frames=100, interval=20, blit=True)
#      33
# ---> 34 HTML(anim.to_html5_video())
#
# C:\Users\hcivi\Anaconda3\lib\site-packages\matplotlib\animation.py in to_html5_video(self)
#    1153                 # We create a writer manually so that we can get the
#    1154                 # appropriate size for the tag
# -> 1155                 Writer = writers[rcParams['animation.writer']]
#    1156                 writer = Writer(codec='h264',
#    1157                                 bitrate=rcParams['animation.bitrate'],
#
# C:\Users\hcivi\Anaconda3\lib\site-packages\matplotlib\animation.py in __getitem__(self, name)
#     127         self.ensure_not_dirty()
#     128         if not self.avail:
# --> 129             raise RuntimeError("No MovieWriters available!")
#     130         return self.avail[name]
#     131
#
# RuntimeError: No MovieWriters available!
